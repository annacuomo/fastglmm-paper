# %%
from IPython.display import display

import pandas as pd
import numpy as np

from horta_exp.introns.fetch_data import get_intron_events

from limix_genetics import hitsplot
from limix_genetics import qqplot

from bokeh.io import output_notebook
from bokeh.plotting import show
from bokeh.charts import Histogram
from bokeh.layouts import gridplot
from bokeh.models import Range1d

FILE = {'real': 'chrom_real_all.pkl', 'null': 'chrom_null_all.pkl'}
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="73d925de-a40c-4e3c-85e7-a69fce5c5b7a">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Introduction
#
#
# There are two files storing the results: `chrom_real_all.pkl` and `chrom_null_all.pkl`.
#
# The first one refers to the results on the real phenotypes (i.e., gene-intron pairs associated
# with correct genetic locus.), whereas the second one refers to results from gene-intron pairs
# randomly associated with genetic locus from different chromossome).
#
# The intron events are retrieved from Blosc-compressed [intron_events_filter4.pkl.blp] file, of a Python Pickle file.
#
# We read those three files and create `df_FILENAME.pkl` and `introns_FILENAME.pkl` files for mere convenience.
#
# [intron_events_filter4.pkl.blp]: https://github.com/glimix/alternative-splicing/blob/master/quant_splicing/transcript-qtls/intron_events_filter4.pkl.blp

# %%
def convert_and_save(filename):
    introns = get_intron_events()
    df = pd.read_pickle(filename).set_index(['gene', 'intron']).sort_index()
    introns = introns.loc[df.index.copy().drop_duplicates()]

    introns.to_pickle('introns_%s.pkl' % filename)
    df.to_pickle('df_%s.pkl' % filename)
    
    return (introns, df)

introns = dict()
df = dict()

if True:
    for n in ['real', 'null']:
        introns[n] = pd.read_pickle('introns_%s.pkl' % FILE[n])
        df[n] = pd.read_pickle('df_%s.pkl' % FILE[n])
else:
    for n in ['real', 'null']:
        (introns[n], df[n]) = convert_and_save(FILE[n])

# %% [markdown]
# We now have dictionaries **introns** and **df** regarding gene-intron events and results, respectively:

# %%
display(introns['real'].head(), df['real'].head())
display(introns['null'].head(), df['null'].head())
# Out:
#                                        assay  nsuc  ntri
# gene            intron
# ENSG00000000419 5       HG00096.1.M_111124_6    37   347
#                 5       HG00097.7.M_120219_2    68   451
#                 5       HG00099.1.M_120209_6    31   327
#                 5       HG00099.5.M_120131_3    34   289
#                 5       HG00100.2.M_111215_8    35   281
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000000419 5          20  0.757149       0.615790  49508683  0.599888
#                 5          20  0.149643       0.489927  49509175  0.523147
#                 5          20  0.466112       0.302470  49509184  0.240761
#                 5          20  0.364057       0.273795  49511295  0.235351
#                 5          20  0.466112       0.302470  49511352  0.240761
#
#                                  snp_id
# gene            intron
# ENSG00000000419 5       snp_20_49508683
#                 5       snp_20_49509175
#                 5       snp_20_49509184
#                 5       snp_20_49511295
#                 5       snp_20_49511352
#                                        assay  nsuc  ntri
# gene            intron
# ENSG00000000419 5       HG00096.1.M_111124_6    37   347
#                 5       HG00097.7.M_120219_2    68   451
#                 5       HG00099.1.M_120209_6    31   327
#                 5       HG00099.5.M_120131_3    34   289
#                 5       HG00100.2.M_111215_8    35   281
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000000419 5          20  0.417235       0.406138  42131442  0.386107
#                 5          20  0.013192       0.014254  42131753  0.009565
#                 5          20  0.969780       0.590113  42132193  0.654554
#                 5          20  0.891230       0.945350  42132273  0.963257
#                 5          20  0.971855       0.857315  42132314  0.891363
#
#                                       snp_id
# gene            intron
# ENSG00000000419 5            snp_19_42131442
#                 5       indel:1I_19_42131753
#                 5            snp_19_42132193
#                 5            snp_19_42132273
#                 5            snp_19_42132314

# %% [markdown]
# The number of evaluated gene-intron pairs is give by **npairs**:

# %%
npairs = len(df['real'].index.unique())
print("Number of gene-intron pairs: %d" % npairs)
# Out:
# Number of gene-intron pairs: 66508

# %% [markdown]
# We can also query the number of evaluated gene-intron pairs across
# chromossomes:

# %%
display(df['real'].groupby(level=[0, 1]).first()
        .groupby('chrom')['chrom'].count())
# Out:
# chrom
# 1     6760
# 2     4938
# 3     4057
# 4     2638
# 5     3082
# 6     3584
# 7     2948
# 8     2257
# 9     3046
# 10    2716
# 11    3810
# 12    3986
# 13    1486
# 14    2353
# 15    2655
# 16    3197
# 17    4296
# 18    1039
# 19    3554
# 20    1723
# 21     710
# 22    1673
# Name: chrom, dtype: int64

# %% [markdown]
# We would like also have a single p-value associated with each
# gene-intron pair, which we do by taking the minimum p-value and
# Bonferroni correcting it in the following section.

# %% [markdown]
# # Bonferroni correction within gene-introns and aggregate the p-values

# %%
def bonferroni_and_aggregate(df):
    def pval_agg(x):
        return np.clip(np.min(x) * len(x), 0, 1)

    return df.groupby(level=[0, 1]).agg({
        'lmm-pval': pval_agg,
        'lmm-rank-pval': pval_agg,
        'qep-pval': pval_agg
    })

df_agg = dict()
for n in ['real', 'null']:
    df_agg[n] = bonferroni_and_aggregate(df[n].copy())
    display(df_agg[n].head())
# Out:
#                         lmm-pval  qep-pval  lmm-rank-pval
# gene            intron
# ENSG00000000419 5       1.000000  1.000000       1.000000
#                 6       1.000000  1.000000       0.405983
#                 7       0.820634  1.000000       1.000000
#                 8       1.000000  1.000000       1.000000
# ENSG00000000457 1       0.007733  0.057588       0.065261
#                         lmm-pval  qep-pval  lmm-rank-pval
# gene            intron
# ENSG00000000419 5       1.000000   1.00000       1.000000
#                 6       1.000000   1.00000       1.000000
#                 7       1.000000   1.00000       1.000000
#                 8       0.278223   0.38103       0.408914
# ENSG00000000457 1       0.039725   1.00000       1.000000

# %% [markdown]
# In order to use `limix_genetics` package to plot we need to conform those dataframes:

# %%
def transpose_df(df):
    DF = dict()
    for n in ['real', 'null']:
        data_list = []
        for method in ['lmm', 'lmm-rank', 'qep']:
            df_ = df[n]['%s-pval' % method]
            pval = df_.astype(float)
            data_list += [pd.DataFrame({'p-value': pval, 'label': method},
                                       index=df_.index)]
        DF[n] = pd.concat(data_list)
        DF[n].sort_index(inplace=True)
        display(DF[n].head())
    return DF

# %%
DF_agg = transpose_df(df_agg)
DF = transpose_df(df)
# Out:
#                            label   p-value
# gene            intron
# ENSG00000000419 5            lmm  1.000000
#                 5       lmm-rank  1.000000
#                 5            qep  1.000000
#                 6            lmm  1.000000
#                 6       lmm-rank  0.405983
#                            label  p-value
# gene            intron
# ENSG00000000419 5            lmm      1.0
#                 5       lmm-rank      1.0
#                 5            qep      1.0
#                 6            lmm      1.0
#                 6       lmm-rank      1.0
#                        label   p-value
# gene            intron
# ENSG00000000419 5        lmm  0.757149
#                 5        lmm  0.149643
#                 5        lmm  0.466112
#                 5        lmm  0.364057
#                 5        lmm  0.466112
#                        label   p-value
# gene            intron
# ENSG00000000419 5        lmm  0.417235
#                 5        lmm  0.013192
#                 5        lmm  0.969780
#                 5        lmm  0.891230
#                 5        lmm  0.971855

# %% [markdown]
# We will subselect results based on number of trials statistics to better understand
# what is going on.

# %%
group = introns['real'].groupby(level=[0, 1]).agg({
    'ntri': {
        'max': 'max',
        'min': 'min',
        'median': 'median',
        'var': 'var',
        'mean': 'mean',
    }
})
group.sort_index(inplace=True)
group.head()
# Out:
#                        ntri
#                         min           var median        mean   max
# gene            intron
# ENSG00000000419 5        29  19941.576410    347  355.765324   951
#                 6         8   8380.139558    218  221.404553   675
#                 7        28  14244.062801    291  294.374781   863
#                 8       104  33432.223345    449  447.775832  1243
# ENSG00000000457 1        73  33727.862918    432  443.460595  1309

# %%
h = Histogram(group['ntri']['min'].values,
               title="Min. number of trials - across gene-intron pairs",
               xlabel='number of trials')
h.x_range = Range1d(0, 120)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f058b3cb-ba60-4a35-baff-b4efbe416f7b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#f058b3cb-ba60-4a35-baff-b4efbe416f7b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f058b3cb-ba60-4a35-baff-b4efbe416f7b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f058b3cb-ba60-4a35-baff-b4efbe416f7b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4153bd78-1229-4dd8-9e73-65c05f4e5b22":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"47bd742f-4fec-42bd-8a01-2c5ee8133efd","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(132.4, 133.1]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(132.4, 133.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.7379679144385136],"x":["132.75"],"y":[0.0]}},"id":"9a47aa53-b92a-4acd-8e08-f230582aa037","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b2870dc7-46d2-43f1-96f4-37b3b253ec35","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cbdd5525-effb-4d0c-afef-09a8464530e5","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(135.3, 136.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(135.3, 136.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.7379679144384852],"x":["135.65"],"y":[0.0]}},"id":"702a69d7-dc10-4cfe-b558-02c3f6407604","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(112.4, 113.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(112.4, 113.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.7379679144384994],"x":["112.80000000000001"],"y":[2.0]}},"id":"a66fa0e5-d02f-46bd-8088-4396e8ac6635","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c8948080-dfa6-41bf-8083-e6baa42e4aa3","type":"ColumnDataSource"},"glyph":{"id":"43fd8337-5a8b-4323-837a-34379de4146e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b38b4c44-50aa-4312-854c-5ef925a204d3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"db265b5f-7498-4006-a5aa-fba77764139b","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(12.8, 13.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1863.0],"label":["(12.8, 13.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.737967914438503],"x":["13.15"],"y":[931.5]}},"id":"a45044a3-1cfa-4bfe-8e21-f20366aae0a8","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e6ad033-576c-4134-ab66-0da84adbe517","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"23580396-2654-4e2c-81cb-addc9063d0d2","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"] ...

# %%
h = Histogram(group['ntri']['max'].values,
               title="Max. number of trials - across gene-intron pairs",
               xlabel='number of trials')
h.x_range = Range1d(0, 3000)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="3ba31d37-a8a2-4ffa-b573-6dd79325af6a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#3ba31d37-a8a2-4ffa-b573-6dd79325af6a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3ba31d37-a8a2-4ffa-b573-6dd79325af6a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3ba31d37-a8a2-4ffa-b573-6dd79325af6a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"44d8cae2-0ec4-4cad-be70-9a33711f6f21":{"roots":{"references":[{"attributes":{"data_source":{"id":"70baca23-7b0d-415d-8700-94067d444ac0","type":"ColumnDataSource"},"glyph":{"id":"c25570bb-7adb-44a8-9078-b99d48ca5867","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"07075d7f-71e4-4b68-b2b8-697e37116b95","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f1ec4ebf-f430-4da2-8002-bd1d504a9877","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f7fa660a-cd84-4f2b-9242-38d46bf817e1","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(15635.0, 15661.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(15635.0, 15661.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[26.492434662999585],"x":["15648.25"],"y":[0.0]}},"id":"113eaf14-c220-466a-b7d5-2a45d2b8e0af","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f5b8d003-4d5b-4f83-b328-32fcc50a62d4","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3686ce68-cd8f-4193-a6c3-22440ee95e65","type":"Rect"},{"attributes":{},"id":"9d120805-94bc-4dd8-817d-73aa56f2a268","type":"BasicTicker"},{"attributes":{"data_source":{"id":"536eadb9-0741-4892-a106-e32f375180ec","type":"ColumnDataSource"},"glyph":{"id":"65acb542-13b3-4215-bd9d-befc62e7f990","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"47b83dba-440e-4267-a270-44590ef6149b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3820a5cc-8284-430a-978e-ef679a392f5a","type":"ColumnDataSource"},"glyph":{"id":"05dc060d-76de-41d5-ac66-22840dc3dfe0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"55ef21e2-4f30-4921-8684-68d190892abe","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6e603235-ca0a-490c-b72a-11148d57a86a","type":"ColumnDataSource"},"glyph":{"id":"98c827c4-4acd-487f-81a2-b98886e93559","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"742f9915-99ee-467e-a967-d7554657d04a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"22eaebd8-00cf-4d09-8766-6808974636a5","type":"ColumnDataSource"},"glyph":{"id":"f509e963-04a9-46bb-909b-8845d617bacf","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"31f75a1c-a70c-4843-ae77-3b3378398a2a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"864a3a67-f0a0-4017-9688-8876e692d0d5","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(9303.4, 9329.8]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(9303.4, 9329.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[26.492434662999585],"x":["9316.599999999999"],"y":[0.0]}},"id":"fdc2ab2 ...

# %%
show(Histogram(group['ntri']['mean'].values,
               title="Mean number of trials - across gene-intron pairs",
               xlabel='number of trials mean'))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1d068847-2502-4f62-9904-78429da8f66c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1d068847-2502-4f62-9904-78429da8f66c").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1d068847-2502-4f62-9904-78429da8f66c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1d068847-2502-4f62-9904-78429da8f66c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8b4781a6-4351-4b19-9cda-86cb3b576f68":{"roots":{"references":[{"attributes":{"data_source":{"id":"a974d8e1-92f6-4214-b8be-f2a591b41c03","type":"ColumnDataSource"},"glyph":{"id":"b244a642-3fcd-479c-abaf-5ddf40acfda9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8dd7f33b-6a33-4427-8957-0e22a3d81c21","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e0ce8b1-f541-4c0e-b11b-4c72ce91da9e","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(80.8, 87.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2221.0],"label":["(80.8, 87.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[7.103327495621713],"x":["84.35"],"y":[1110.5]}},"id":"e335214c-0b2c-44fe-97c5-fbed862202b8","type":"ColumnDataSource"},{"attributes":{},"id":"72d35103-6128-4075-8857-1d5b38532009","type":"BasicTicker"},{"attributes":{"data_source":{"id":"6a66754c-40f7-4c80-9560-a655c58841f7","type":"ColumnDataSource"},"glyph":{"id":"aeda5e9b-1392-433d-96e8-7a912d2af0d1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"805754be-14a3-4436-a96e-d37088c290d8","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1efa38cd-44ef-48b2-8c80-18454c0b4a4b","type":"ColumnDataSource"},"glyph":{"id":"4891fb7e-f78a-4e5a-8b1c-ff24e395e5a5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e69b644e-ef31-4320-9a8b-1e6ebca92efe","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"4df0759f-5d99-4eb3-8f4d-4944c9efc77e","type":"ColumnDataSource"},"glyph":{"id":"26d243f0-fdc0-493c-b222-76adecd4f2a5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b7d6e5c5-db4e-4981-be6d-dbd75ab2b9ae","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(428.9, 436.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[133.0],"label":["(428.9, 436.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[7.103327495621727],"x":["432.45"],"y":[66.5]}},"id":"bfda0a0a-f4ad-4fa4-b228-89293fd3bac3","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e42a9ff0-f677-46b1-881b-d238264bd61b","type":"Rect"},{"attributes":{"data_source":{"id":"9ce0f963-018c-4569-8034-b162ca128c35","type":"ColumnDataSource"},"glyph":{"id":"a0524528-d493-4ace-b6aa-33a7ba100a6b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"54c7f3c7-7962-4afd-b4ef-b1ede06f8168","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2a84995a-ab3f-4aea-a586-a94e604acda2","type":"Rect"},{"attributes":{"data_source":{"id":"006a7af9-2834-4a13-adbc-71e600d3506a","type":"ColumnDataSource"},"glyph":{"id":"fab397d9-8450-4cfc-a00f-157f311f0ed9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"45e2ccea-5c56-4bc9-bdd8-2ea53697d8a2","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"372058de-91d7-4b1f-95df-96b136714bcc","type":"ColumnDataSource"},"glyph":{"id":"2d128d2b-d047-43ff-aca9-125223f4d669","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6364a7ba-11 ...

# %%
show(Histogram(group['ntri']['median'].values,
               title="Median number of trials - across gene-intron pairs",
               xlabel='number of trials median'))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="27e2e4b4-e2f8-4235-bb05-c81e8182bb4b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#27e2e4b4-e2f8-4235-bb05-c81e8182bb4b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("27e2e4b4-e2f8-4235-bb05-c81e8182bb4b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '27e2e4b4-e2f8-4235-bb05-c81e8182bb4b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"34e0bf13-8c0c-4219-9a4b-b509eb0bc590":{"roots":{"references":[{"attributes":{"overlay":{"id":"0a2ad691-93f5-416a-af2b-dc64798b8d02","type":"BoxAnnotation"},"plot":{"id":"aa9bbc04-53a6-4926-84bc-e049f272bf98","subtype":"Chart","type":"Plot"}},"id":"fd30bc1c-e914-42bb-925c-ed5c72426d43","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5fdebc79-9b0f-4f09-b1cc-a7181d138aec","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(347.0, 353.7]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[288.0],"label":["(347.0, 353.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[6.628205128205138],"x":["350.35"],"y":[144.0]}},"id":"73d3091e-d024-4edc-b39e-2f1816d4956f","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"aa9bbc04-53a6-4926-84bc-e049f272bf98","subtype":"Chart","type":"Plot"}},"id":"24f94e81-7308-4328-8efd-44f2cd389053","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9dfe0320-9d7f-4465-9cc8-405aff005896","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(207.8, 214.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1011.0],"label":["(207.8, 214.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[6.62820512820511],"x":["211.15"],"y":[505.5]}},"id":"2d944afc-9b05-4b5a-9947-b6f32798f3ff","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(101.8, 108.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2017.0],"label":["(101.8, 108.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[6.628205128205138],"x":["105.1"],"y":[1008.5]}},"id":"b56288a5-f966-4b70-b685-1543a011b85d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b701ae95-504b-4fe6-940d-cb9f00177d3f","type":"ColumnDataSource"},"glyph":{"id":"9c1a8ebf-c1c8-4917-8315-af75008e0ce3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1d183f5c-2e36-4b71-8248-e3c74e94f452","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"35cbab42-05cf-46f9-9a13-671dfba552a8","type":"Rect"},{"attributes":{"data_source":{"id":"a102c6ac-6126-41d7-9aaf-b015d79ec1a5","type":"ColumnDataSource"},"glyph":{"id":"515f4e61-f399-4464-a0d4-b482e4c9794c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7e40ba8f-98a2-4626-b8f7-b2cafc72fd4d","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"29b3cdfb-6048-4fc4-b1f5-65dc6ab7d632","type":"ColumnDataSource"},"glyph":{"id":"6c629a52-3da6-492c-9832-495264be0a8c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f8562f83-e278-425d-85f5-30865bfa6040","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c53d4aaa-c4e3-47c9-9ed2-027780a88c9f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units" ...

# %%
h = Histogram(group['ntri']['var'].values,
               title="Var number of trials - across gene-intron pairs",
               xlabel='number of trials variance')
h.x_range = Range1d(0, 60000)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="141ae154-ffd4-4cf2-be98-0c689a226608"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#141ae154-ffd4-4cf2-be98-0c689a226608").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("141ae154-ffd4-4cf2-be98-0c689a226608");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '141ae154-ffd4-4cf2-be98-0c689a226608' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"92dc332c-b642-4938-a50e-7c1f7294ede9":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"31110435-8d25-401f-88a2-e846025b032e","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(638369.9, 638897.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(638369.9, 638897.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[527.9911260212539],"x":["638633.9"],"y":[0.0]}},"id":"ea6fb934-356f-43de-bb3d-5cac964853a7","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"f6459db8-1ac0-4640-9c1d-62cd75221b7d","type":"ColumnDataSource"},"glyph":{"id":"a20766b2-8615-4e74-8c5b-651dc1e953ea","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e9e236c4-e8bd-4e62-b4fd-3988d1893706","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"12d993e1-1cbf-4268-9e69-6724d08191f2","type":"ColumnDataSource"},"glyph":{"id":"4c56a18d-6ace-43ec-a550-75d4f231a8b7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f0418cb4-6b3c-4fd1-b4de-e677fd750d29","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1b09430d-4b5f-4122-9e2d-db77cbd8c851","type":"ColumnDataSource"},"glyph":{"id":"03c9c342-a905-49ff-981a-4dcb621d149e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"70e3c0aa-74ad-4664-815a-32f88b276980","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8dbaf409-b3a9-48bd-959b-d86757b99d33","type":"ColumnDataSource"},"glyph":{"id":"0e6ae61b-9dae-4d8a-88d7-5fc6da2f435e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"df55efad-7cc1-49d5-a500-c1de9a19acdd","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"657e28a0-f651-4ea1-9082-a77ffaa99bab","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(543331.5, 543859.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(543331.5, 543859.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[527.9911260212539],"x":["543595.5"],"y":[0.0]}},"id":"1743c9fe-cae3-4451-9f90-fd6919fa57c0","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"78a6006e-3b28-44d7-b18a-433afd8b6124","type":"ColumnDataSource"},"glyph":{"id":"718b9fbb-92d0-4b4a-9e3f-60e36c78f4e2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"31335607-74b5-4e2b-a710-4e30ee4d8bdd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c7ae44d3-9e35-4607-babd-57d532f30222","type":"ColumnDataSource"},"glyph":{"id":"73aeeebf-3100-42ea-9a3d-2878306d195e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"25b15082-f90e-4014-81e8-93751063e63d","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"a71a5d1b-6cb1-448b-b9ef-7a62c9cb478a","type":"ColumnDataSource"},"glyph":{"id":"20f2f1e9-c380-4385-a948-2f69eadfac86","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"15bdc627-346a-439e-ae8e-d99f5a99e374","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","line_color","color","line_alpha","y","label","height","fill_alpha","width"],"data":{"chart_index":["(158954.0, 159482.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(158954.0, 159482.0]"],"line_alpha":[1.0],"line_color":["black"],"w ...

# %%
from bokeh.plotting import figure
f = figure()

groupA = group[group['ntri']['mean'] < 100]
groupB = group[(group['ntri']['mean'] >= 100) & (group['ntri']['var'] < 10000)]
groupC = group[(group['ntri']['mean'] >= 100) & (group['ntri']['var'] >= 10000)]

f.circle(groupA['ntri']['var'], groupA['ntri']['mean'], color='red')
f.circle(groupB['ntri']['var'], groupB['ntri']['mean'], color='green')
f.circle(groupC['ntri']['var'], groupC['ntri']['mean'], color='blue')

f.x_range = Range1d(0, group['ntri']['var'].quantile(0.999))
f.xaxis.axis_label = 'Variance( number of trials )'
f.yaxis.axis_label = 'Mean( number of trials )'

# %% [markdown]
# # Gene-intron variance versus mean number of trials
#
# - red group  : small mean                    (groupA)
# - green group: high mean and small variance  (groupB)
# - blue group : hight mean and hight variance (groupC)

# %%
show(f)

# %%
def plot_grid(DF, DF_agg, ntri, introns, STAT):
    
    size = 400
    colors={'lmm': 'blue', 'qep': 'red', 'lmm-rank': 'green'}
    
    df_agg = DF_agg['real'].loc[ntri.index].copy()
    df_agg['p-value'] = np.clip(df_agg['p-value'] * npairs, 0, 1)
    
    df = DF['real'].loc[ntri.index].copy()
    
    hits0 = hitsplot(df_agg, colors=colors, perc=True,
                     width=size, height=size, min_threshold=1e-5, max_threshold=1e-2,
                     show=False)
    
    qq0 = qqplot(df, colors=colors, atleast_points=0.005, show=False,
                width=size, height=size)
    
    df_agg = DF_agg['null'].loc[ntri.index].copy()
    df_agg['p-value'] = np.clip(df_agg['p-value'] * npairs, 0, 1)
    
    df = DF['null'].loc[ntri.index].copy()
    
    hits1 = hitsplot(df_agg, colors=colors,
         perc=True, width=size, height=size, min_threshold=1e-5, max_threshold=1e-2,
        show=False)
    
    qq1 = qqplot(df, colors=colors, atleast_points=0.005, show=False,
                 width=size, height=size)

    
    def choice(vals):
        return np.random.RandomState(0).choice(vals, min(8000, len(vals)))
    
    ntris = choice(introns.loc[ntri.index]['ntri'].values)
    hist0 = Histogram(ntris, title="Number of trials - across samples",
                   tools=['save'], xlabel='number of trials',
                   width=size, height=size)
    hist0.x_range = Range1d(0, np.percentile(ntris, 99.9))
    
    values = choice(ntri[STAT].values)
    hist1 = Histogram(values, title="%s number of trials - across gene-intron pairs" % STAT,
                   tools=['save'], xlabel='number of trials', width=size, height=size)
    hist1.x_range = Range1d(0, np.percentile(values, 99.9)),
    
    show(gridplot([[hits0, hits1], [qq0, qq1], [hist0, hist1]]))

# %% [markdown]
# ## Group A

# %%
plot_grid(DF, DF_agg, groupA['ntri'].copy(), introns['real'], 'min')

# %% [markdown]
# ## Group B

# %%
plot_grid(DF, DF_agg, groupB['ntri'].copy(), introns['real'], 'min')

# %% [markdown]
# ## Group C

# %%
plot_grid(DF, DF_agg, groupC['ntri'].copy(), introns['real'], 'min')

# %%
DF_agg.head()

# %%
import pickle as pkl

group.to_pickle('horta_group.pkl')

with open("horta_DF.pkl","wb") as f:
    pkl.dump(DF, f, -1)

with open("horta_DF_agg.pkl","wb") as f:
    pkl.dump(DF_agg, f, -1)

with open("horta_introns.pkl","wb") as f:
    pkl.dump(introns, f, -1)
