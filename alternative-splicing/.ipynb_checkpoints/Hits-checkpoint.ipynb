# %%
import pandas as pd
import numpy as np


chrom = 22
df = pd.read_pickle('chrom_%d.pkl' % chrom)
df.set_index(['gene', 'intron'], inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000015475 7          22  0.190543       0.083220  18207220  0.235661
#                 7          22  0.990685       0.813105  18207251  0.639112
#                 7          22  0.367290       0.777673  18207730  0.867640
#                 7          22  0.524754       0.607386  18207780  0.418764
#                 7          22  0.836786       0.175274  18207927  0.758660
#
#                                       snp_id
# gene            intron
# ENSG00000015475 7            snp_22_18207220
#                 7            snp_22_18207251
#                 7            snp_22_18207730
#                 7       indel:1I_22_18207780
#                 7            snp_22_18207927

# %% [markdown]
# # Bonferroni correction

# %%
ntests = len(df)
print("Number of tests: %d" % ntests)
df['lmm-pval'] = np.clip(df['lmm-pval'] * ntests, 0, 1)
df['lmm-rank-pval'] = np.clip(df['lmm-rank-pval'] * ntests, 0, 1)
df['qep-pval'] = np.clip(df['qep-pval'] * ntests, 0, 1)
# Out:
# Number of tests: 141942

# %%
from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file
from bokeh.charts import BoxPlot, Bar
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2854cbc1-18f3-4dfd-a9e5-43815e6db124">Loading BokehJS ...</span>
#     </div>

# %%
def plot_for_thr(pval_thr, perc=False):

    data = pd.DataFrame(columns=('pval', 'method', 'color'))

    def append_df(data, df, name):
        N = len(df['%s-pval' % name])
        d = [np.asarray(df['%s-pval' % name]), [name] * N]
        data = pd.concat([data, pd.DataFrame({'pval': d[0], 'method': d[1], 'color': ['white'] * N})])
        return data

    data = append_df(data, df, 'lmm')
    data = append_df(data, df, 'lmm-rank')
    data = append_df(data, df, 'qep')

    data.loc[data['method'] == 'lmm', 'color'] = 'blue'
    data.loc[data['method'] == 'lmm-rank', 'color'] = 'green'
    data.loc[data['method'] == 'qep', 'color'] = 'red'


    if perc:
        grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: 100*sum(x<=pval_thr)/float(len(x))})
    else:
        grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: sum(x<=pval_thr)})

    grouped.loc['lmm', 'color'] = 'blue'
    grouped.loc['lmm-rank', 'color'] = 'green'
    grouped.loc['qep', 'color'] = 'red'

    p = Bar(grouped, values='pval', color='color', label='method', legend=False,
           title = "Chromossome %d :: p-value < %.0e" % (chrom, pval_thr), tools=['save,reset'], height=400, width=400)

    if perc:
        p.yaxis.axis_label = 'Percentage of hits (p-value < %.0e)' % (pval_thr, )
    else:
        p.yaxis.axis_label = 'Number of hits (p-value < %.0e)' % (pval_thr, )

    show(p)

# %% [markdown]
# # Number of Hits

# %%
plot_for_thr(1e-5)
plot_for_thr(1e-1)
plot_for_thr(1.0)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c7b1214a-0127-4dd1-ac89-50a389c36c93"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c7b1214a-0127-4dd1-ac89-50a389c36c93").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c7b1214a-0127-4dd1-ac89-50a389c36c93");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c7b1214a-0127-4dd1-ac89-50a389c36c93' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"504f6b6f-24f7-4ce9-9a83-d2830e97853a":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b510bfa7-fc2f-4754-8769-7190d51336a0","type":"Rect"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3f9ad0ed-7dcd-4bbe-9691-adea79628b85","type":"SaveTool"},{"id":"5dc717b1-33d7-4c5c-b1fd-dd815833c042","type":"ResetTool"}]},"id":"b51cc1ee-3a18-4b0c-8109-5ce094fca04d","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6a2fd535-c29d-466f-89a6-6bdcdd6a0d7d","type":"Rect"},{"attributes":{"axis_label":"Method","formatter":{"id":"e3227c75-ae46-4e95-8d71-b547d8679b8b","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"4a3a3963-8fc4-4613-a8e6-32dec5f789c3","subtype":"Chart","type":"Plot"},"ticker":{"id":"d3eeafc0-266b-4c37-8d10-58e7e511880b","type":"CategoricalTicker"}},"id":"822b109b-82c1-4cee-92fc-64f99a259be7","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ce99fca1-3717-4073-8cef-13778406a473","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"blue","method":"lmm"}],"color":["blue"],"fill_alpha":[0.8],"height":[627.0],"label":[{"color":"blue","method":"lmm"}],"line_alpha":[1.0],"line_color":["white"],"method":["lmm"],"width":[0.8],"x":["lmm"],"y":[313.5]}},"id":"4565616f-6717-4376-9968-8a7b57f00fb3","type":"ColumnDataSource"},{"attributes":{},"id":"b547e1c3-f89f-47d0-a3ec-41d863055199","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"4565616f-6717-4376-9968-8a7b57f00fb3","type":"ColumnDataSource"},"glyph":{"id":"ce99fca1-3717-4073-8cef-13778406a473","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c73c7ee1-a6db-499f-a4ff-35f180f04c0a","type":"GlyphRenderer"},{"attributes":{},"id":"e3227c75-ae46-4e95-8d71-b547d8679b8b","type":"CategoricalTickFormatter"},{"attributes":{},"id":"0553308d-7ad8-4e33-9c01-8c678af405d0","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Chromossome 22 :: p-value < 1e-05"},"id":"5fa143f6-4a01-4bd1-8ce4-cc22070f950e","type":"Title"},{"attributes":{},"id":"b44fad1e-d8f0-439f-b8f3-325737f5f612","type":"ToolEvents"},{"attributes":{"data_source":{"id":"8ec5d445-3a64-44dd-ad15-dbea68612814","type":"ColumnDataSource"},"glyph":{"id":"6a2fd535-c29d-466f-89a6-6bdcdd6a0d7d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e146dc7a-e0b4-40ba-92ca-939468898ac2","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"red","method":"qep"}],"color":["red"],"fill_alpha":[0.8],"height":[4220.0],"label":[{"color":"red","method":"qep"}],"line_alpha":[1.0],"line_color":["white"],"method":["qep"],"width":[0.8],"x":["qep"],"y":[2110.0]}},"id":"8ec5d445-3a64-44dd-ad15-dbea68612814","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"da0b50c8-a397-4a4b-ae1e-3e196e06cff4","type":"ColumnDataSource"},"glyph":{"id":"b510bfa7-fc2f-4754-8769-7190d51336a0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a23407aa-3300-4f4b-b9e8-b8bb5592d686","type":"GlyphRenderer"},{"attributes":{"below":[ ...
#     <div class="bk-root">
#         <div class="plotdiv" id="ec12869b-40b1-455e-874d-0a2a5c09f710"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#ec12869b-40b1-455e-874d-0a2a5c09f710").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ec12869b-40b1-455e-874d-0a2a5c09f710");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ec12869b-40b1-455e-874d-0a2a5c09f710' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"78123464-8779-4756-8120-1a5a43cd1401":{"roots":{"references":[{"attributes":{"callback":null,"factors":["lmm","lmm-rank","qep"]},"id":"f94dfde7-fd99-4d30-abb2-e615d4468b0b","type":"FactorRange"},{"attributes":{"axis_label":"Number of hits (p-value < 1e-01)","formatter":{"id":"d2c63ae6-e39e-4b38-acb5-f4f23cfe83db","type":"BasicTickFormatter"},"plot":{"id":"6082a46f-366b-4299-8f1f-b7f234ea6104","subtype":"Chart","type":"Plot"},"ticker":{"id":"9da4aa1c-17c3-47b6-b493-d773c3b215a6","type":"BasicTicker"}},"id":"20e786a7-7bd6-4650-a6ec-c6167732def9","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"98693eb9-9d51-4bc6-b993-64db5259ef55","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"red","method":"qep"}],"color":["red"],"fill_alpha":[0.8],"height":[4765.0],"label":[{"color":"red","method":"qep"}],"line_alpha":[1.0],"line_color":["white"],"method":["qep"],"width":[0.8],"x":["qep"],"y":[2382.5]}},"id":"45a79ae2-c090-4356-9076-492bcf4ec4e3","type":"ColumnDataSource"},{"attributes":{"axis_label":"Method","formatter":{"id":"afc828e6-82ba-4264-afb4-ef2be0fc0618","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"6082a46f-366b-4299-8f1f-b7f234ea6104","subtype":"Chart","type":"Plot"},"ticker":{"id":"1f95ed0a-b0a2-4de8-a5ed-9c59bfd85793","type":"CategoricalTicker"}},"id":"5376cbed-f390-4e32-8ac6-efadfb144b20","type":"CategoricalAxis"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"green","method":"lmm-rank"}],"color":["green"],"fill_alpha":[0.8],"height":[0.0],"label":[{"color":"green","method":"lmm-rank"}],"line_alpha":[1.0],"line_color":["white"],"method":["lmm-rank"],"width":[0.8],"x":["lmm-rank"],"y":[0.0]}},"id":"75a96973-9ca7-4823-a7fe-e00a57f20527","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"6082a46f-366b-4299-8f1f-b7f234ea6104","subtype":"Chart","type":"Plot"},"ticker":{"id":"9da4aa1c-17c3-47b6-b493-d773c3b215a6","type":"BasicTicker"}},"id":"83b74964-b315-421d-8b3f-56cf53b5fa7b","type":"Grid"},{"attributes":{"callback":null,"end":5003.25},"id":"ec4567db-58e9-4bda-a1c9-d5c9dbf6f37d","type":"Range1d"},{"attributes":{"data_source":{"id":"75a96973-9ca7-4823-a7fe-e00a57f20527","type":"ColumnDataSource"},"glyph":{"id":"ee813e4c-317e-4e4b-b3bb-8ab38fc38ae0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"81769b5c-00d4-436e-a276-d4f9de714e1a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2d65e00e-5024-407f-bbfa-a04567364c85","type":"Rect"},{"attributes":{"plot":null,"text":"Chromossome 22 :: p-value < 1e-01"},"id":"7b8a930f-852a-4601-b525-28b383514b8b","type":"Title"},{"attributes":{"data_source":{"id":"c768ff30-fae9-4ce2-9ea0-fd4cc364c2e2","type":"ColumnDataSource"},"glyph":{"id":"98693eb9-9d51-4bc6-b993-64db5259ef55","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a02c124a-1bfc-47d5-b9ae-23335d85c3ce","type":"GlyphRenderer"},{"attributes":{},"id":"afc828e6-82ba-4264-afb4-ef2be0fc0618","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"blue","method":"lmm"}],"color":["blue"],"fill_alpha":[0.8],"height":[1416.0],"label":[{"color":"blue","method":"lmm"} ...
#     <div class="bk-root">
#         <div class="plotdiv" id="c87774c9-d15a-4b5b-89ef-3d71f79fe513"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c87774c9-d15a-4b5b-89ef-3d71f79fe513").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c87774c9-d15a-4b5b-89ef-3d71f79fe513");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c87774c9-d15a-4b5b-89ef-3d71f79fe513' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9679e827-a11b-46cc-a499-cdefe07dc85b":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e8608ad4-b889-4956-8eec-9962e39e753c","type":"Rect"},{"attributes":{"axis_label":"Method","formatter":{"id":"22ac5298-5902-4ec4-93c7-aca18a615b3a","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"fc9d3486-8a3b-40fd-82c9-56655f043e0e","subtype":"Chart","type":"Plot"},"ticker":{"id":"c3cedf0a-c022-482a-a062-4688789594c0","type":"CategoricalTicker"}},"id":"1e86b8c6-92be-4092-814b-0fb9964af5f9","type":"CategoricalAxis"},{"attributes":{},"id":"22ac5298-5902-4ec4-93c7-aca18a615b3a","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"fc9d3486-8a3b-40fd-82c9-56655f043e0e","subtype":"Chart","type":"Plot"}},"id":"8d6c5486-5ec1-47f3-93ea-7ace93f444da","type":"SaveTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d9d07fe7-d891-4bdf-b16d-d9177b322639","type":"Rect"},{"attributes":{},"id":"c3cedf0a-c022-482a-a062-4688789594c0","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"green","method":"lmm-rank"}],"color":["green"],"fill_alpha":[0.8],"height":[141942.0],"label":[{"color":"green","method":"lmm-rank"}],"line_alpha":[1.0],"line_color":["white"],"method":["lmm-rank"],"width":[0.8],"x":["lmm-rank"],"y":[70971.0]}},"id":"fb89f1c5-83ed-4389-ab85-c32b9b92e7c7","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3cd2f8b9-c459-4100-958f-adea0b9b987b","type":"Rect"},{"attributes":{"callback":null,"end":149039.1},"id":"c211bd95-9e1e-4161-b587-0a619526693a","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"blue","method":"lmm"}],"color":["blue"],"fill_alpha":[0.8],"height":[141942.0],"label":[{"color":"blue","method":"lmm"}],"line_alpha":[1.0],"line_color":["white"],"method":["lmm"],"width":[0.8],"x":["lmm"],"y":[70971.0]}},"id":"f857a9c4-8e41-4e7d-b917-3283aab2df1f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"6cee27e9-095b-4bfa-8338-ce75a43f1c80","type":"ColumnDataSource"},"glyph":{"id":"d9d07fe7-d891-4bdf-b16d-d9177b322639","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5130a99a-49cb-4529-bd17-f57c14330e96","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"Chromossome 22 :: p-value < 1e+00"},"id":"903b5b61-b974-468d-833c-f03ba4856c10","type":"Title"},{"attributes":{},"id":"1d4be957-29e7-4c4d-bc2b-2787d6c21877","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"fc9d3486-8a3b-40fd-82c9-56655f043e0e","subtype":"Chart","type":"Plot"},"ticker":{"id":"408af4b4-fc11-43e7-a2f7-2e773bdba25a","type":"BasicTicker"}},"id":"b7ab46ec-0e67-4ade-9dbd-5d1ea08ccc53","type":"Grid"},{"attributes":{"plot":{"id":"fc9d3486-8a3b-40fd-82c9-56655f043e0e","subtype":"Chart","type":"Plot"}},"id":"8dfd779a-aa66-4e54-9563-599eee492747","type":"ResetTool"},{"attributes":{"data_source":{"id":"fb89f1c5-83ed-4389-ab85-c32b9b92e7c7","type":"ColumnDataSource"},"glyph":{"id":"3cd2f8b9-c459-4100-958f-adea0b9b987b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e2ee7275-0a2e-47e8-890c-caa2a55e9b2 ...

# %% [markdown]
# # Percentage of Hits

# %%
plot_for_thr(1e-5, True)
plot_for_thr(1e-1, True)
plot_for_thr(1.0, True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c78d2aed-ec17-4d1d-b279-127dd67591a7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c78d2aed-ec17-4d1d-b279-127dd67591a7").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c78d2aed-ec17-4d1d-b279-127dd67591a7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c78d2aed-ec17-4d1d-b279-127dd67591a7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1c42bf3e-7f92-476d-9980-026aa984f952":{"roots":{"references":[{"attributes":{"plot":{"id":"87e68439-7b0f-478b-8066-8f79b70d9a85","subtype":"Chart","type":"Plot"}},"id":"c1953bb3-0eb9-4d31-b8f8-6f6588697d32","type":"ResetTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f9558f7-cc6f-47e0-9178-0840a72f5304","type":"Rect"},{"attributes":{},"id":"14c2b20a-1ae1-4995-824a-8e8f32774527","type":"BasicTicker"},{"attributes":{},"id":"a08ab810-c57c-433e-9ccd-bc106f8c5726","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"87e68439-7b0f-478b-8066-8f79b70d9a85","subtype":"Chart","type":"Plot"}},"id":"d70bada6-9804-4ee8-9d37-44031c8770a3","type":"SaveTool"},{"attributes":{},"id":"641ff77e-1b89-48ec-ba32-effadc9495d2","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3f10238d-78cf-48bd-abbc-8de883e7753d","type":"Rect"},{"attributes":{"data_source":{"id":"7cf290a7-ebd1-4e02-a806-72a9f6c6913d","type":"ColumnDataSource"},"glyph":{"id":"7f9558f7-cc6f-47e0-9178-0840a72f5304","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3ba4ca9f-193e-4e6c-96db-d9b5f5124552","type":"GlyphRenderer"},{"attributes":{},"id":"f1dacd1a-26dd-4542-a2fe-257cfa21ffe4","type":"ToolEvents"},{"attributes":{"below":[{"id":"da457c6c-1d0c-450f-a1b9-fdfed2ad59e2","type":"CategoricalAxis"}],"height":400,"left":[{"id":"a8dc89e5-e982-4096-8555-b857ac6c9879","type":"LinearAxis"}],"renderers":[{"id":"3ba4ca9f-193e-4e6c-96db-d9b5f5124552","type":"GlyphRenderer"},{"id":"7feb265e-7236-4967-8734-024604e17ed3","type":"GlyphRenderer"},{"id":"e90c9ea5-8969-40fb-bf7b-95cee4670f7f","type":"GlyphRenderer"},{"id":"da457c6c-1d0c-450f-a1b9-fdfed2ad59e2","type":"CategoricalAxis"},{"id":"a8dc89e5-e982-4096-8555-b857ac6c9879","type":"LinearAxis"},{"id":"b78330bd-cc44-4182-aaff-270dabb0ffbc","type":"Grid"}],"title":{"id":"31b5037b-63a0-4d00-b7bd-942be158025b","type":"Title"},"tool_events":{"id":"f1dacd1a-26dd-4542-a2fe-257cfa21ffe4","type":"ToolEvents"},"toolbar":{"id":"7c390c96-c046-4f24-9361-7f37e4275d35","type":"Toolbar"},"width":400,"x_mapper_type":"auto","x_range":{"id":"cfc7bba4-311d-48de-b7c9-d449ef37dd72","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"c68eece4-772a-4a4d-8f44-723baeaabc0c","type":"Range1d"}},"id":"87e68439-7b0f-478b-8066-8f79b70d9a85","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"end":3.121697594792239},"id":"c68eece4-772a-4a4d-8f44-723baeaabc0c","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"blue","method":"lmm"}],"color":["blue"],"fill_alpha":[0.8],"height":[0.4417297205901002],"label":[{"color":"blue","method":"lmm"}],"line_alpha":[1.0],"line_color":["white"],"method":["lmm"],"width":[0.8],"x":["lmm"],"y":[0.2208648602950501]}},"id":"7cf290a7-ebd1-4e02-a806-72a9f6c6913d","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"green","method":"lmm-rank"}],"color":["green"],"fill_alpha":[0.8],"height":[0.0],"label":[{"color":"green","method":"lmm-rank"}],"line_alpha":[1.0],"line_color":["white"],"method":["lmm-rank"],"width":[0.8],"x":["lmm-rank"],"y":[0.0]}},"id":"8412f6f9-5eaa-4c5b-85ac-2d0825b65f36","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d5da8a44-4bce-4530-b9c7-5260f1ae0135","type":"ColumnDataSource"},"glyph":{"id":"3f10238d-78cf-48bd-abbc-8de883e7753d","t ...
#     <div class="bk-root">
#         <div class="plotdiv" id="ffecea9d-c28d-4fda-931e-ba4e30344d24"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#ffecea9d-c28d-4fda-931e-ba4e30344d24").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ffecea9d-c28d-4fda-931e-ba4e30344d24");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ffecea9d-c28d-4fda-931e-ba4e30344d24' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4dc25c04-9f3a-4491-b64a-99b28b1a0731":{"roots":{"references":[{"attributes":{},"id":"907a540d-0ebc-4ae6-9c84-5f4facffe950","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ef6acd1a-69f5-4682-a35c-f1ce8eaa4aa9","type":"Rect"},{"attributes":{"data_source":{"id":"4909acdb-15fd-4af3-a9a8-d39bd1240216","type":"ColumnDataSource"},"glyph":{"id":"ef6acd1a-69f5-4682-a35c-f1ce8eaa4aa9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d9bc3dce-45ce-49a0-8847-f59491c26d25","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["lmm","lmm-rank","qep"]},"id":"df830ca3-d874-44cf-8af3-0e96e8af3324","type":"FactorRange"},{"attributes":{"callback":null,"end":3.524855222555692},"id":"b99bb2cc-7df1-45c6-a16c-faa6eecca4a3","type":"Range1d"},{"attributes":{},"id":"4975c8ab-4129-46a6-a79a-75dc183847a3","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Percentage of hits (p-value < 1e-01)","formatter":{"id":"4975c8ab-4129-46a6-a79a-75dc183847a3","type":"BasicTickFormatter"},"plot":{"id":"27e354f0-a1f6-411a-8aec-d898753a7fba","subtype":"Chart","type":"Plot"},"ticker":{"id":"66c5ef4e-3831-423e-bc97-c793d4b04447","type":"BasicTicker"}},"id":"5e5c4e0c-575d-4d33-ac25-fe6bb242de5d","type":"LinearAxis"},{"attributes":{"data_source":{"id":"2b2b3196-5d51-4f3f-8a9f-bd389ea07a6c","type":"ColumnDataSource"},"glyph":{"id":"ea4e7f3c-bb12-4eee-a65f-172dfb8865a3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"069c1e6a-fca5-4ffc-894e-93161bcd6607","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"blue","method":"lmm"}],"color":["blue"],"fill_alpha":[0.8],"height":[0.9975905651604177],"label":[{"color":"blue","method":"lmm"}],"line_alpha":[1.0],"line_color":["white"],"method":["lmm"],"width":[0.8],"x":["lmm"],"y":[0.49879528258020883]}},"id":"2b2b3196-5d51-4f3f-8a9f-bd389ea07a6c","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"949dae6e-3727-4f66-abaa-687d7cceed0a","type":"SaveTool"},{"id":"38355378-0a90-47de-b926-e86e17e9a37e","type":"ResetTool"}]},"id":"f045d8e2-33d4-473a-93dc-78fb1b989ca6","type":"Toolbar"},{"attributes":{"plot":null,"text":"Chromossome 22 :: p-value < 1e-01"},"id":"78efc55b-a42a-431a-b4ca-7f121cb68be7","type":"Title"},{"attributes":{"axis_label":"Method","formatter":{"id":"907a540d-0ebc-4ae6-9c84-5f4facffe950","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"27e354f0-a1f6-411a-8aec-d898753a7fba","subtype":"Chart","type":"Plot"},"ticker":{"id":"78d82510-f564-4e7d-b3a4-3b5e29a91e39","type":"CategoricalTicker"}},"id":"208d3b18-de49-4d1b-a0f5-a5d89bc1b155","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"09fe8487-b2e3-4047-a5d8-dd9add306b33","type":"ColumnDataSource"},"glyph":{"id":"2d85baec-9f1f-4d01-9250-f48f01d0337c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ef0cf07a-0ecf-4854-8da6-bc5e474d998e","type":"GlyphRenderer"},{"attributes":{},"id":"78d82510-f564-4e7d-b3a4-3b5e29a91e39","type":"CategoricalTicker"},{"attributes":{},"id":"66c5ef4e-3831-423e-bc97-c793d4b04447","type":"BasicTicker"},{"attributes":{},"id":"dff62b1f-bba8-49f9-ba7d-8654f48e0799","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ea4e7f3c-bb12-4eee-a65f-172dfb8865a3","type":"Rect"},{"attributes":{"plot":{ ...
#     <div class="bk-root">
#         <div class="plotdiv" id="d764d194-1476-40ac-841a-fd6b52e3d1eb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#d764d194-1476-40ac-841a-fd6b52e3d1eb").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d764d194-1476-40ac-841a-fd6b52e3d1eb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd764d194-1476-40ac-841a-fd6b52e3d1eb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2cb1fd6e-5d53-4933-bcba-9c16e2f1d188":{"roots":{"references":[{"attributes":{"plot":null,"text":"Chromossome 22 :: p-value < 1e+00"},"id":"35607524-1e4e-4fe9-bf76-8c678c8c5e9d","type":"Title"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"green","method":"lmm-rank"}],"color":["green"],"fill_alpha":[0.8],"height":[100.0],"label":[{"color":"green","method":"lmm-rank"}],"line_alpha":[1.0],"line_color":["white"],"method":["lmm-rank"],"width":[0.8],"x":["lmm-rank"],"y":[50.0]}},"id":"dd78b09f-56a4-4aec-abef-054bc195512b","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"ffdc79a1-5fc8-4303-999f-070d980258f5","subtype":"Chart","type":"Plot"}},"id":"71dde311-bf1d-4596-85d2-5ab97ee38e9e","type":"SaveTool"},{"attributes":{"callback":null,"end":105.0},"id":"6351f86c-1540-4185-8359-f166f7d2ea60","type":"Range1d"},{"attributes":{"axis_label":"Percentage of hits (p-value < 1e+00)","formatter":{"id":"870b2caa-a222-4c29-90a0-32007adea5d2","type":"BasicTickFormatter"},"plot":{"id":"ffdc79a1-5fc8-4303-999f-070d980258f5","subtype":"Chart","type":"Plot"},"ticker":{"id":"213ba5f4-2bcf-47ba-b501-d6cb1ecbc724","type":"BasicTicker"}},"id":"bc36f3f0-3e8c-408e-bfb7-b453d2cf8e66","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"94154398-0d65-4747-8d0b-4fbbd4990031","type":"Rect"},{"attributes":{"axis_label":"Method","formatter":{"id":"b7a016ea-3f4f-487d-8f09-fcf8a338cccd","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"ffdc79a1-5fc8-4303-999f-070d980258f5","subtype":"Chart","type":"Plot"},"ticker":{"id":"dee40919-8993-4dab-a2b1-977df2ad3b44","type":"CategoricalTicker"}},"id":"757bd224-c3ce-4172-b663-6c6090ca4782","type":"CategoricalAxis"},{"attributes":{},"id":"213ba5f4-2bcf-47ba-b501-d6cb1ecbc724","type":"BasicTicker"},{"attributes":{"callback":null,"factors":["lmm","lmm-rank","qep"]},"id":"891b6289-a6f1-484e-8108-19190a66f997","type":"FactorRange"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d82a84a3-2ec9-40f5-887f-fb691061a748","type":"Rect"},{"attributes":{"below":[{"id":"757bd224-c3ce-4172-b663-6c6090ca4782","type":"CategoricalAxis"}],"height":400,"left":[{"id":"bc36f3f0-3e8c-408e-bfb7-b453d2cf8e66","type":"LinearAxis"}],"renderers":[{"id":"f9ee6f91-44b6-4b6f-9c87-5ef288407248","type":"GlyphRenderer"},{"id":"2c635270-4605-4239-a6b3-9fee54a14fcd","type":"GlyphRenderer"},{"id":"04232274-f987-4e3c-b6f8-3d4c96f5c28c","type":"GlyphRenderer"},{"id":"757bd224-c3ce-4172-b663-6c6090ca4782","type":"CategoricalAxis"},{"id":"bc36f3f0-3e8c-408e-bfb7-b453d2cf8e66","type":"LinearAxis"},{"id":"cc5e85a2-e23f-49d0-be81-ce6b2d20e346","type":"Grid"}],"title":{"id":"35607524-1e4e-4fe9-bf76-8c678c8c5e9d","type":"Title"},"tool_events":{"id":"83075f89-e4b6-42da-9c2e-f1da2d8ea363","type":"ToolEvents"},"toolbar":{"id":"cf8c5448-4734-4b77-a39e-959106e03eee","type":"Toolbar"},"width":400,"x_mapper_type":"auto","x_range":{"id":"891b6289-a6f1-484e-8108-19190a66f997","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"6351f86c-1540-4185-8359-f166f7d2ea60","type":"Range1d"}},"id":"ffdc79a1-5fc8-4303-999f-070d980258f5","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["line_alpha","label","line_color","x","width","fill_alpha","y","height","color"],"data":{"chart_index":[{"color":"red","method":"qep"}],"color":["red"],"fill_alpha":[0.8],"height":[100.0],"label":[{"color":"red","method":"qep"}],"line_alpha":[1.0],"line_color":["white"],"met ...
