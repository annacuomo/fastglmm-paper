# %%
import pandas as pd
import numpy as np


chrom = 22
df = pd.read_pickle('chrom_%d.pkl' % chrom)
df.set_index(['gene', 'intron'], inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000025770 1          22  0.613807       0.480221  50896901  0.389656
#                 1          22  0.316533       0.574893  50897215  0.533459
#                 1          22  0.043711       0.138918  50897314  0.099098
#                 1          22  0.514677       0.750123  50897692  0.828003
#                 1          22  0.000753       0.021789  50897868  0.007409
#
#                                  snp_id
# gene            intron
# ENSG00000025770 1       snp_22_50896901
#                 1       snp_22_50897215
#                 1       snp_22_50897314
#                 1       snp_22_50897692
#                 1       snp_22_50897868

# %% [markdown]
# # Bonferroni correction

# %%
ntests = len(df)
print("Number of tests: %d" % ntests)
df['lmm-pval'] = np.clip(df['lmm-pval'] * ntests, 0, 1)
df['lmm-rank-pval'] = np.clip(df['lmm-rank-pval'] * ntests, 0, 1)
df['qep-pval'] = np.clip(df['qep-pval'] * ntests, 0, 1)
# Out:
# Number of tests: 134108

# %%
from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file
from bokeh.charts import BoxPlot, Bar
from bokeh.layouts import gridplot
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3fdcf84f-eeb8-41d2-888a-f377a2efebde">Loading BokehJS ...</span>
#     </div>

# %%
def plot_curve(perc=False, exclude=False, lthr=-5, rthr=-0.30103):

    data = pd.DataFrame(columns=('pval', 'method', 'color'))

    def append_df(data, df, name):
        N = len(df['%s-pval' % name])
        # BONFERRONI ACROSS THE ENTIRE SET OF GENE-INTRON PAIRS
        d = [np.asarray(df['%s-pval' % name]), [name] * N]
        data = pd.concat([data, pd.DataFrame({'pval': d[0], 'method': d[1]})])
        return data

    data = append_df(data, df, 'lmm')
    data = append_df(data, df, 'lmm-rank')
    data = append_df(data, df, 'qep')
    
    nhits = {'lmm-rank':[], 'qep':[]}
    if not exclude:
        nhits['lmm'] = []
    
    pts = np.logspace(lthr, rthr)
    for pt in pts:

        if perc:
            grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: 100*sum(x<=pt)/float(len(x))})
        else:
            grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: sum(x<=pt)})


        nhits['lmm-rank'].append(grouped.loc['lmm-rank', 'pval'])
        if not exclude:
            nhits['lmm'].append(grouped.loc['lmm', 'pval'])
        nhits['qep'].append(grouped.loc['qep', 'pval'])

    p = figure(title="Power", tools=['save,reset'])
    p.grid.grid_line_alpha=0.3
    p.xaxis.axis_label = 'P-value threshold'
    if perc:
        p.yaxis.axis_label = 'Percentage of hits'
    else:
        p.yaxis.axis_label = 'Number of hits'
    p.line(pts, nhits['lmm-rank'], color='green', legend='lmm-rank')
    if not exclude:
        p.line(pts, nhits['lmm'], color='blue', legend='lmm')
    p.line(pts, nhits['qep'], color='red', legend='qep')
    p.legend.location = "bottom_right"
    return p

# %%
p1 = plot_curve(True)
p2 = plot_curve(True, True)
p3 = plot_curve(False)
p4 = plot_curve(False, True)
show(gridplot([[p1,p2],[p3,p4]], plot_width=400, plot_height=400))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id
subtype":"Figure","type":"Plot"},{"attributes":{},"id":"4b0364c7-2ec2-480a-9238-17e28f20fe95","type":"ToolEvents"},{"attributes":{"plot":null,"text":"Power"},"id":"e908334d-9500-44f1-bc5e-a9f77d48a212","type":"Title"},{"attributes":{"axis_label":"P-value threshold","formatter":{"id":"965dd199-f302-4180-ad99-77f98bcd7d1c","type":"BasicTickFormatter"},"plot":{"id":"a5c20e56-588a-471b-958a-3e9f8bd1220c","subtype":"Figure","type":"Plot"},"ticker":{"id":"3963bf80-fba7-4b52-9d8e-84d9dda26c96","type":"BasicTicker"}},"id":"eb25cb79-bf2d-4928-a5c7-9208f10e170f","type":"LinearAxis"},{"attributes":{"plot":{"id":"a5c20e56-588a-471b-958a-3e9f8bd1220c","subtype":"Figure","type":"Plot"}},"id":"382c5f5a-002a-45ee-bbce-aa52071aa967","type":"ResetTool"},{"attributes":{},"id":"db35caf4-c6f0-4c0a-801e-33af36e0f3ea","type":"BasicTicker"},{"attributes":{},"id":"f7414c49-57f9-4711-b7ae-f545baf64f0c","type":"BasicTicker"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"54dea4d5-715a-406b-b3cd-32371c2ee5f6","subtype":"Figure","type":"Plot"},"ticker":{"id":"7a2b6f1e-c7e3-4199-aad2-5b14ce05b7b9","type":"BasicTicker"}},"id":"3858be63-ae86-4d1d-8365-85cdb3862f20","type":"Grid"},{"attributes":{"line_color":{"value":" ...

# %%
lthr = -10
rthr = -2
p1 = plot_curve(True, lthr=lthr, rthr=rthr)
p2 = plot_curve(True, True, lthr=lthr, rthr=rthr)
p3 = plot_curve(False, lthr=lthr, rthr=rthr)
p4 = plot_curve(False, True, lthr=lthr, rthr=rthr)
show(gridplot([[p1,p2],[p3,p4]], plot_width=400, plot_height=400))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0fe39a03-0eed-4f10-8146-0ce8f46a192f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#0fe39a03-0eed-4f10-8146-0ce8f46a192f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0fe39a03-0eed-4f10-8146-0ce8f46a192f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0fe39a03-0eed-4f10-8146-0ce8f46a192f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bd3fcfc4-5c25-4fa4-9920-190a0628dd18":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c2a8b420-541d-4153-b674-8a3ccd78533f","type":"Line"},{"attributes":{"callback":null},"id":"531b62df-3b1a-45c8-a9aa-5f02caef4ca3","type":"DataRange1d"},{"attributes":{"label":{"value":"qep"},"renderers":[{"id":"86d66168-bf0e-40fa-baf5-eaef0675bddb","type":"GlyphRenderer"}]},"id":"f8ec4ffe-5b67-4633-97f5-4101e14fba6a","type":"LegendItem"},{"attributes":{"axis_label":"P-value threshold","formatter":{"id":"53a08269-5f98-43f5-8032-18ef48060f6f","type":"BasicTickFormatter"},"plot":{"id":"9a236a4e-de60-40d9-9324-8791009b95e4","subtype":"Figure","type":"Plot"},"ticker":{"id":"383dae8f-0152-4545-8110-5da7f53bb6e9","type":"BasicTicker"}},"id":"316d24df-db40-451f-9501-e39d54877b1f","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[