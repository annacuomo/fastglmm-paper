# %%
import pandas as pd
import numpy as np


data = pd.read_pickle('chrom_real.pkl')
data.set_index(['gene', 'intron'], inplace=True)
data.sort_index(inplace=True)
data.head()
# Out:
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000000419 5          20  0.230234       0.615790  49508683  0.599888
#                 5          20  0.018827       0.489927  49509175  0.523147
#                 5          20  0.712852       0.302470  49509184  0.240761
#                 5          20  0.484039       0.273795  49511295  0.235351
#                 5          20  0.712852       0.302470  49511352  0.240761
#
#                                  snp_id
# gene            intron
# ENSG00000000419 5       snp_20_49508683
#                 5       snp_20_49509175
#                 5       snp_20_49509184
#                 5       snp_20_49511295
#                 5       snp_20_49511352

# %% [markdown]
# # Bonferroni correction

# %%
ntests = len(data.index.unique())
print("Number of tests: %d" % ntests)

# Bonferroni within gene-intron
def pval_agg(x):
    return np.clip(np.min(x) * len(x), 0, 1)

def method_agg(x):
    return x[0]
    
def gene_intron_wise(df):
    return data.groupby(level=[0, 1]).agg({
        'lmm-pval': pval_agg,
        'lmm-rank-pval': pval_agg,
        'qep-pval': pval_agg
    })

data = gene_intron_wise(data)
# Out:
# Number of tests: 68454

# %%
data.head()
# Out:
#                         lmm-pval  lmm-rank-pval  qep-pval
# gene            intron
# ENSG00000000419 5       0.094760       1.000000  1.000000
#                 6       0.000951       0.405983  1.000000
#                 7       0.000011       1.000000  1.000000
#                 8       1.000000       1.000000  1.000000
# ENSG00000000457 1       0.191699       0.065261  0.057588

# %%
def method_column(df):
    newdata = pd.DataFrame(columns=('pval', 'method'))

    def append_df(data, df, name):
        pval = df['%s-pval' % name]
        return pd.concat([data, pd.DataFrame({'pval': pval, 'method': name})])
        return data

    newdata = append_df(newdata, df, 'lmm')
    newdata = append_df(newdata, df, 'lmm-rank')
    newdata = append_df(newdata, df, 'qep')
    return newdata

# %%
def set_index(data):
    data = method_column(data)
    data.reset_index(inplace=True)
    data['gene'] = data['index'].apply(lambda x: x[0])
    data['intron'] = data['index'].apply(lambda x: int(x[1]))
    del data['index']
    data.set_index(['gene', 'intron'], inplace=True)
    data.sort_index(inplace=True)
    return data

# %%
data = set_index(data)

# %%
from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file
from bokeh.charts import BoxPlot, Bar
from bokeh.layouts import gridplot
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6af251c2-6a18-438e-aa26-143c8afd7d4b">Loading BokehJS ...</span>
#     </div>

# %%
data.head()
# Out:
#                           method      pval
# gene            intron
# ENSG00000000419 5            lmm  0.094760
#                 5       lmm-rank  1.000000
#                 5            qep  1.000000
#                 6            lmm  0.000951
#                 6       lmm-rank  0.405983

# %%
def plot_curve(data, perc=False, exclude=False, lthr=-5, rthr=-0.30103):
    
    nhits = {'lmm-rank':[], 'qep':[]}
    if not exclude:
        nhits['lmm'] = []
    
    pts = np.logspace(lthr, rthr)
    for pt in pts:

        if perc:
            grouped = data.groupby(data['method']).agg({
                'pval': lambda x: 100*sum(x*len(x)<=pt)/float(len(x))
            })
        else:
            grouped = data.groupby(data['method']).agg({
                'pval': lambda x: sum(x*len(x)<=pt)
            })


        nhits['lmm-rank'].append(grouped.loc['lmm-rank', 'pval'])
        if not exclude:
            nhits['lmm'].append(grouped.loc['lmm', 'pval'])
        nhits['qep'].append(grouped.loc['qep', 'pval'])

    p = figure(title="Power", tools=['save,reset'])
    p.grid.grid_line_alpha=0.3
    p.xaxis.axis_label = 'P-value threshold'
    if perc:
        p.yaxis.axis_label = 'Percentage of hits'
    else:
        p.yaxis.axis_label = 'Number of hits'
    p.line(pts, nhits['lmm-rank'], color='green', legend='lmm-rank')
    if not exclude:
        p.line(pts, nhits['lmm'], color='blue', legend='lmm')
    p.line(pts, nhits['qep'], color='red', legend='qep')
    p.legend.location = "bottom_right"
    return p

# %%
lthr = -5
rthr = -1
p1 = plot_curve(data, False, lthr=lthr, rthr=rthr)
p2 = plot_curve(data, False, True, lthr=lthr, rthr=rthr)
show(gridplot([[p1,p2]], plot_width=400, plot_height=400))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="57274e18-1f14-4f38-bef1-d86759776cbe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#57274e18-1f14-4f38-bef1-d86759776cbe").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("57274e18-1f14-4f38-bef1-d86759776cbe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '57274e18-1f14-4f38-bef1-d86759776cbe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1b6cef50-4cd2-49e6-a120-855e71e2ab30":{"roots":{"references":[{"attributes":{},"id":"5dfaba40-5a53-44e9-b3cd-8a0582e08fe2","type":"BasicTicker"},{"attributes":{"plot":{"id":"b504ddd1-ad5b-43e2-9c83-13f0d8ea3915","subtype":"Figure","type":"Plot"}},"id":"cc09f1a7-2a79-416d-8125-43633f978ccf","type":"ResetTool"},{"attributes":{"plot":null,"text":"Power"},"id":"9995ba9a-6ffc-426c-828a-ffdcd38e9896","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"86000e0b-19fe-4bb1-89f6-d46716624a55","type":"Line"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f4a4c1a5-7e3c-4dfc-bac4-7ddba643c2cc","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1e-05,1.2067926406393289e-05,1.4563484775012445e-05,1.757510624854793e-05,2.1209508879201926e-05,2.559547922699533e-05,3.0888435964774785e-05,3.727593720314938e-05,4.498432668969444e-05,5.4286754393238594e-05,6.55128556859551e-05,7.906043210907701e-05,9.540954763499944e-05,0.00011513953993264469,0.00013894954943731373,0.00016768329368110067,0.00020235896477251554,0.000244205309454865,0.00029470517025518097,0.00035564803062231287,0.00042919342601287783,0.0005179474679231213,0.0006250551925273969,0.0007543120063354615,0.0009102981779915217,0.0010985411419875584,0.0013257113655901081,0.0015998587196060573,0.0019306977288832496,0.002329951810515372,0.002811768697974228,0.0033932217718953264,0.004094915062380423,0.004941713361323833,0.005963623316594642,0.007196856730011514,0.00868511373751352,0.010481131341546853,0.012648552168552958,0.015264179671752318,0.018420699693267144,0.022229964825261933,0.026826957952797246,0.032374575428176434,0.039069399370546126,0.047148663634573894,0.05689866029018293,0.06866488450042998,0.08286427728546843,0.1],"y":[1423.0,1434.0,1449.0,1458.0,1480.0,1497.0,1506.0,1523.0,1539.0,1555.0,1570.0,1584.0,1596.0,1618.0,1632.0,1649.0,1662.0,1677.0,1694.0,1713.0,1722.0,1749.0,1768.0,1780.0,1804.0,1824.0,1840.0,1867.0,1883.0,1909.0,1930.0,1953.0,1978.0,2006.0,2023.0,2053.0,2075.0,2094.0,2118.0,2137.0,2164.0,2193.0,2216.0,2246.0,2271.0,2297.0,2332.0,2371.0,2397.0,2428.0]}},"id":"229e7220-bd89-4c58-b2d3-1578070e0acd","type":"ColumnDataSource"},{"attributes":{"items":[{"id":"60c31770-cdf1-457b-94aa-4c863cd7bf07","type":"LegendItem"},{"id":"72b23682-7a4c-4efc-9fe4-e00a847c360e","type":"LegendItem"},{"id":"bc0df99c-6b0c-416d-acfd-6d18b45710d1","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"5abdca6f-e13c-48d0-8db5-d771129ce126","subtype":"Figure","type":"Plot"}},"id":"a61e86fa-7196-400c-821e-0537bb238169","type":"Legend"},{"attributes":{"label":{"value":"qep"},"renderers":[{"id":"ca42367e-8853-4a5c-b47d-b1fcb7acb032","type":"GlyphRenderer"}]},"id":"bc0df99c-6b0c-416d-acfd-6d18b45710d1","type":"LegendItem"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"b504ddd1-ad5b-43e2-9c83-13f0d8ea3915","subtype":"Figure","type":"Plot"},"ticker":{"id":"e78fffac-4da4-404e-a566-b8e782b866bb","type":"BasicTicker"}},"id":"e3555518-413a-4f92-8403-ac0ee6058b5d","type":"Grid"},{"attributes":{"plot":{"id":"5abdca6f-e13c-48d0-8db5-d771129ce126","subtype":"Figure","type":"Plot"}},"id":"5a185fb3-e82f-425d-9bd1-66f9a2da0ffb","type":"SaveTool"},{"attributes":{"data_source":{"id":"24bb0242-78ef-4fed-97bd-08509b68afa3","type":"ColumnDataSource"},"glyph":{"id":"0acc0d65-6a43-4ca1-aeef-c1425bb71fa2","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"26a3982f-975e-478f-8a97-98c90f34d691","type":"Line"},"selection_glyph":null},"id":"d2e3f244-fd3b-49fb-8b0a-eef0c0240e66","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"6277bfb4-2b9d-4b24-ac84-8e61bf893d43","type":"DataRange1d"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"283dfcea-3c5a-40bf-9698-3d8e23dcab89","type":"Line"},{"attributes":{"plot":{"id":"5abdca6f-e13c-48d0-8db5-d771129ce126","subtyp ...

# %%
from horta_exp.introns.fetch_data import get_intron_events
introns = get_intron_events()
introns.head()
# Out:
#                                        assay  nsuc  ntri
# gene            intron
# ENSG00000000419 5       HG00096.1.M_111124_6    37   347
#                 5       HG00097.7.M_120219_2    68   451
#                 5       HG00099.1.M_120209_6    31   327
#                 5       HG00099.5.M_120131_3    34   289
#                 5       HG00100.2.M_111215_8    35   281

# %%
def plot_data(data, title='title'):
    print(title)
    lthr = -5
    rthr = -1
    p1 = plot_curve(data, True, lthr=lthr, rthr=rthr)
    p2 = plot_curve(data, True, True, lthr=lthr, rthr=rthr)
    show(gridplot([[p1,p2]], plot_width=400, plot_height=400, title=title))

# %%
g = introns.groupby(level=[0, 1])
g = g.agg({
    'ntri': {
        'max': 'max',
        'min': 'min',
    },
    'nsuc': {
        'max': 'max',
        'min': 'min',
    }
})
g.head()
# Out:
#                        nsuc      ntri
#                         max min   max  min
# gene            intron
# ENSG00000000419 5       148   5   951   29
#                 6         9   0   675    8
#                 7        50   0   863   28
#                 8       571   4  1243  104
# ENSG00000000457 1        83   0  1309   73

# %%
for th in range(50, 501, 50):
    d = data.loc[g['ntri']['max'] < th]
    plot_data(d, title='Max #ntrials: %d; Number of gene-introns: %d' % (th, len(d.index.unique())))

th = 1000
d = data.loc[g['ntri']['max'] < th]
plot_data(d, title='Max #ntrials: %d; Number of gene-introns: %d' % (th, len(d.index.unique())))

th = 10000
d = data.loc[g['ntri']['max'] < th]
plot_data(d, title='Max #ntrials: %d; Number of gene-introns: %d' % (th, len(d.index.unique())))
# Out:
# Max #ntrials: 50; Number of gene-introns: 43
#     <div class="bk-root">
#         <div class="plotdiv" id="1c825783-1e2b-4a50-8ba2-565245f669fb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1c825783-1e2b-4a50-8ba2-565245f669fb").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1c825783-1e2b-4a50-8ba2-565245f669fb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1c825783-1e2b-4a50-8ba2-565245f669fb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"86083178-c424-48f7-982b-80ae6ee75d9d":{"roots":{"references":[{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0391c644-d46a-47cd-a9f4-0c1c1ab3d7ee","type":"Line"},{"attributes":{"callback":null},"id":"77fed128-d0ff-4307-8cf5-d4a76bef3c91","type":"DataRange1d"},{"attributes":{"items":[{"id":"03df3138-d15d-4655-9429-da28005ae8cf","type":"LegendItem"},{"id":"506ca49b-a185-4cc1-85ed-830b86fc980d","type":"LegendItem"},{"id":"1cba2d18-9269-491b-a77c-d1be84c3565f","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"d192558c-27bf-409b-bee9-e419bb10ab76","subtype":"Figure","type":"Plot"}},"id":"a36140ab-b5ad-4ec8-975a-5a1236dc2fc5","type":"Legend"},{"attributes":{"callback":null},"id":"bdbb9489-8de8-445e-895b-9edf40972ffb","type":"DataRange1d"},{"attributes":{"below":[{"id":"9997b00a-93dc-461b-9913-d3530c329c69","type":"LinearAxis"}],"left":[{"id":"56632770-8c53-428b-96c4-c257f2e7e1b0","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"9997b00a-93dc-461b-9913-d3530c329c69","type":"LinearAxis"},{"id":"f7c5582a-670a-4b68-9273-b3fa9d905e56","type":"Grid"},{"id":"56632770-8c53-428b-96c4-c257f2e7e1b0","type":"LinearAxis"},{"id":"1d5d605f-81a4-4000-bd75-88c3069653a2","type":"Grid"},{"id":"d51e4d7a-78e1-479f-bdf2-185dd387aed7","type":"Legend"},{"id":"d4e6a021-937d-4b5d-b1c9-53307e4ad1de","type":"GlyphRenderer"},{"id":"ca0bc3c7-f8ce-43b7-8bb4-c8139dcfe4ef","type":"GlyphRenderer"}],"title":{"id":"8251650e-5029-45f5-af7a-29b51d3b1a8a","type":"Title"},"tool_events":{"id":"4cf5cd02-2959-410c-8c17-4884ca577431","type":"ToolEvents"},"toolbar":{"id":"6a9c0396-3b21-4f79-aad6-78ab53df4100","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"77fed128-d0ff-4307-8cf5-d4a76bef3c91","type":"DataRange1d"},"y_range":{"id":"bdbb9489-8de8-445e-895b-9edf40972ffb","type":"DataRange1d"}},"id":"1bbd9da7-708f-4d8f-973c-755e63f792d3","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"5d682493-b4a9-4570-900b-7b8af55e08d3","type":"BasicTicker"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"d192558c-27bf-409b-bee9-e419bb10ab76","subtype":"Figure","type":"Plot"},"ticker":{"id":"5d682493-b4a9-4570-900b-7b8af55e08d3","type":"BasicTicker"}},"id":"6dec8bd4-b352-4ff3-83a7-72cf84e31a86","type":"Grid"},{"attributes":{},"id":"d4c70117-7ce7-4247-825b-d73e11ac4345","type":"BasicTickFormatter"},{"attributes":{"axis_label":"
},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"985bc669-46ca-4888-95f5-de741991c873","type":"SaveTool"},{"id":"bc9fb7e8-5ad7-43e5-84e7-fa8bfb503228","type":"ResetTool"},{"id":"7f565b85-688d-4021-bbfd-461eb1ffba5a","type":"SaveTool"} ...
# Max #ntrials: 200; Number of gene-introns: 8462
#     <div class="bk-root">
#         <div class="plotdiv" id="b08d400f-14a5-4824-9e44-659b156b96de"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b08d400f-14a5-4824-9e44-659b156b96de").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b08d400f-14a5-4824-9e44-659b156b96de");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b08d400f-14a5-4824-9e44-659b156b96de' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"63fde193-2df3-4d8b-94de-84f3afb1329b":{"roots":{"references":[{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3894efb6-463c-4075-84cd-ce43c17c5a76","type":"Line"},{"attributes":{"plot":{"id":"82fd7f70-ab68-4e23-a228-02ce39ce07a1","subtype":"Figure","type":"Plot"}},"id":"5141c694-05d1-462c-b981-5bde82d0e21c","type":"SaveTool"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"c1548f8e-000f-4703-ab0f-d6e6cb0ed2a0","subtype":"Figure","type":"Plot"},"ticker":{"id":"3ced568e-6612-4cb2-af94-f6d2145a3942","type":"BasicTicker"}},"id":"414d822c-c8c8-4b83-a631-9353d6f9cdfc","type":"Grid"},{"attributes":{"callback":null},"id":"8dff672d-f477-48a1-8d14-74cca696b32c","type":"DataRange1d"},{"attributes":{},"id":"d44e3699-905b-4354-be54-ea31fb869bc4","type":"BasicTickFormatter"},{"attributes":{"axis_label":"P-value threshold","formatter":{"id":"48f4ba36-cbce-471a-929a-5f80dff1d823","type":"BasicTickFormatter"},"plot":{"id":"82fd7f70-ab68-4e23-a228-02ce39ce07a1","subtype":"Figure","type":"Plot"},"ticker":{"id":"620844f2-ba2d-4e86-87f5-999c6460b61a","type":"BasicTicker"}},"id":"663f082d-f1f3-4399-a09c-dc273e5b2c97","type":"LinearAxis"},{"attributes":{},"id":"8da9c317-87a0-4b8e-befa-6203b5e4f3a9","type":"BasicTicker"},{"attributes":{"data_source":{"id":"92dc14f5-0014-44cd-aded-581fa5ffebb6","type":"ColumnDataSource"},"glyph":{"id":"89b799e1-6dae-40c0-bc9a-de30b9255ce3","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"b1ca3d5d-74e1-4853-a50a-009e0f467944","type":"Line"},"selection_glyph":null},"id":"7d400ee1-0841-40c6-bd79-cf6b917d264a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"631c5199-3312-479b-aea7-1d4b9b7327c5","type":"ColumnDataSource"},"glyph":{"id":"e161fd08-3126-4686-9577-aef8505d850e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c3a20c9d-6047-47b0-abd2-fe3983f34609","type":"Line"},"selection_glyph":null},"id":"1bd157cf-c83e-4e5c-bae9-27f4f2ff72a9","type":"GlyphRenderer"},{"attributes":{"label":{"value":"lmm-rank"},"renderers":[{"id":"1bd157cf-c83e-4e5c-bae9-27f4f2ff72a9","type":"GlyphRenderer"}]},"id":"1f6118eb-250b-4f18-85e0-a227248fd505","type":"LegendItem"},{"attributes":{"children":[{"id":"a09e4bdc-08a2-4702-84d7-4eb032964b23","type":"Row"}]},"id":"570b85d7-2ac9-478a-bc55-84545f7f3ca8","type":"Column"},{"attributes":{},"id":"e4d7321d-c07a-4676-9541-7cf03d67f116","type":"ToolEvents"},{"attributes":{"below":[{"id":"663f082d-f1f3-4399-a09c-dc273e5b2c97","type":"LinearAxis"}],"left":[{"id":"53500df9-473a-4c6b-b1a9-8262fd7e8c35","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"663f082d-f1f3-4399-a09c-dc273e5b2c97","type":"LinearAxis"},{"id":"cc311bae-472a-470a-8b25-7610cb97217b","type":"Grid"},{"id":"53500df9-473a-4c6b-b1a9-8262fd7e8c35","type":"LinearAxis"},{"id":"4dcd51a7-e1ed-4950-bfeb-b7415ceed31e","type":"Grid"},{"id":"693f8794-1096-4ba3-8c6f-522c341944c4","type":"Legend"},{"id":"c27b0233-c70b-4513-8221-3efe7564038e","type":"GlyphRenderer"},{"id":"7d400ee1-0841-40c6-bd79-cf6b917d264a","type":"GlyphRenderer"}],"title":{"id":"d2fcbc94-fcb7-4c3b-aa8a-bf0fa618da44","type":"Title"},"tool_events":{"id":"6f3c1a66-ae06-463b-ac1f-1530cc649d28","type":"ToolEvents"},"toolbar":{"id":"8f603e22-09ba-467b-afb5-89197c507beb","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"71564a84-66a5-405b-8865-4f6bdad7ae7e","type":"DataRange1d"},"y_range":{"id":"01dd0b7d-be9c-4296-b55d-0d378b9e7fc1","type":"DataRange1d"}},"id":"82fd7f70-ab68-4e23-a228-02ce39ce07a1","subtype":"Figure","type":"Plot"},{"attributes":{"below":[{"id":"cfd08288-43e3-4b85-a7fe-89f2cb9fa8c1","type":"LinearAxis"}],"left":[{"id":"b314becb-dcb8-46c7-a11a-90d5c5650cc7","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"cfd08288-43e3-4b85-a7fe-89f2cb9fa8c1","type":"LinearAxis"},{"id":"414d822c-c8c8-4b83-a631-9353d6f9cdfc","type":"Grid"},{"id":"b314becb-dcb8-46c7-a11a-90d5c5650cc7","type":"LinearAxis"},{" ...
# Max #ntrials: 250; Number of gene-introns: 12839
#     <div class="bk-root">
#         <div class="plotdiv" id="4cbc16e6-4dda-44c9-81cf-dddf329e42f8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#4cbc16e6-4dda-44c9-81cf-dddf329e42f8").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4cbc16e6-4dda-44c9-81cf-dddf329e42f8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4cbc16e6-4dda-44c9-81cf-dddf329e42f8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"15356c32-08a3-4d85-abc6-c912d59cd25a":{"roots":{"references":[{"attributes":{},"id":"db1553fc-4fe0-4d1f-8813-6dfe6f80ca4a","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac737bbe-1421-4e23-b059-2fd436d0a04f","type":"Line"},{"attributes":{},"id":"cf36336a-1007-4f55-b5be-6d7346e6f596","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"32fff072-fc49-4de9-b533-9cdec049d422","type":"Line"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"48641ffe-a733-4df5-b4ff-ce1503eb9ecc","type":"Line"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"bd45db61-447f-412f-9997-6e9ebc84f56d","subtype":"Figure","type":"Plot"},"ticker":{"id":"84360fd9-2ca6-4ad9-9b57-ad7a2589af4b","type":"BasicTicker"}},"id":"014f1e23-71e7-4c17-9a78-4e15256396d9","type":"Grid"},{"attributes":{"data_source":{"id":"3604ec7f-bd3e-4217-8801-6fc558856543","type":"ColumnDataSource"},"glyph":{"id":"7ec48fa1-de68-458b-93be-8fd274c93408","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":
but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f34bc45c-d3b5-42b8-a709-214df8b53087":{"roots":{"references":[{"attributes":{"plot":{"id":"a362e1a1-b947-4050-856d-bd55c37f5458","subtype":"Figure","type":"Plot"}},"id":"5ac26aab-124b-4c05-b243-3d9118346399","type":"SaveTool"},{"attributes":{"dimension":1,"grid_line_alpha":{"value":0.3},"plot":{"id":"a362e1a1-b947-4050-856d-bd55c37f5458","subtype":"Figure","type":"Plot"},"ticker":{"id":"3adb5f13-8745-4158-83b6-d39a26b12d8f","type":"BasicTicker"}},"id":"dcaa2252-e8bb-4cc3-8ce9-7db53eec5966","type":"Grid"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a68dddb6-976b-497d-87c9-51af7e9c1331","type":"Line"},{"attributes":{"plot":{"id":"1ef9e965-e528-474d-8b2e-49373389917e","subtype":"Figure","type":"Plot"}},"id":"100a1ec5-66a4-4550-9fea-e995daa1ddf6","type":"ResetTool"},{"attributes":{"axis_label":"Percentage of hits","formatter":{"id":"9b58d805-e3b3-4eea-bc59-5c17b4d64e9d","type":"BasicTickFormatter"},"plot":{"id":"1ef9e965-e528-474d-8b2e-49373389917e","subtype":"Figure","type":"Plot"},"ticker":{"id":"62566331-ff6f-493d-b5cc-063f96ba9e01","type":"BasicTicker"}},"id":"d98be680-bb62-4554-8762-835a37b5ff40","type":"LinearAxis"},{"attributes":{},"id":"3adb5f13-8745-4158-83b6-d39a26b12d8f","type":"BasicTicker"},{"attributes":{"callback":null},"id":"956ef02f-5d2d-455a-90a3-6e0e632ca11a","type":"DataRange1d"},{"attributes":{},"id":"026a3bb6-e5b7-4152-92f4-bc41fd82bf28","type":"BasicTicker"},{"attributes":{"callback":null},"id":"95b06621-cae7-47ab-8821-d7cd35fb76b6","type":"DataRange1d"},{"attributes":{"children":[{"id":"065bba87-4602-47fb-8c08-b2be9c43729a","type":"Row"}]},"id":"b3ab991d-3070-4141-a87e-867f79be3849","type":"Column"},{"attributes":{"plot":{"id":"a362e1a1-b947-4050-856d-bd55c37f5458","subtype":"Figure","type":"Plot"}},"id":"7e5ef3f3-5ea6-4f2e-a4c9-234e0884728a","type":"ResetTool"},{"attributes":{"axis_label":"Percentage of hits","formatter":{"id":"894e46a5-9dca-4332-b63b-00b29690563e","type":"BasicTickFormatter"},"plot":{"id":"a362e1a1-b947-4050-856d-bd55c37f5458","subtype":"Figure","type":"Plot"},"ticker":{"id":"3adb5f13-8745-4158-83b6-d39a26b12d8f","type":"BasicTicker"}},"id":"617c03cf-7602-4193-a312-2c5dda5769c1","type":"LinearAxis"},{"attributes":{},"id":"894e46a5-9dca-4332-b63b-00b29690563e","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1e-05,1.2067926406393289e-05,1.4563484775012445e-05,1.757510624854793e-05,2.1209508879201926e-05,2.559547922699533e-05,3.0888435964774785e-05,3.727593720314938e-05,4.498432668969444e-05,5.4286754393238594e-05,6.55128556859551e-05,7.906043210907701e-05,9.540954763499944e-05,0.00011513953993264469,0.00013894954943731373,0.00016768329368110067,0.00020235896477251554,0.000244205309454865,0.00029470517025518097,0.00035564803062231287,0.00042919342601287783,0.0005179474679231213,0.0006250551925273969,0.0007543120063354615,0.0009102981779915217,0.0010985411419875584,0.0013257113655901081,0.0