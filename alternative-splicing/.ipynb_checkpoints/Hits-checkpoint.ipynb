# %%
import pandas as pd
import numpy as np


chrom = 22
df = pd.read_pickle('chrom_%d.pkl' % chrom)
df.set_index(['gene', 'intron'], inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000015475 7          22  0.190543       0.083220  18207220  0.235661
#                 7          22  0.990685       0.813105  18207251  0.639112
#                 7          22  0.367290       0.777673  18207730  0.867640
#                 7          22  0.524754       0.607386  18207780  0.418764
#                 7          22  0.836786       0.175274  18207927  0.758660
#
#                                       snp_id
# gene            intron
# ENSG00000015475 7            snp_22_18207220
#                 7            snp_22_18207251
#                 7            snp_22_18207730
#                 7       indel:1I_22_18207780
#                 7            snp_22_18207927

# %% [markdown]
# # Bonferroni correction

# %%
ntests = len(df)
print("Number of tests: %d" % ntests)
df['lmm-pval'] = np.clip(df['lmm-pval'] * ntests, 0, 1)
df['lmm-rank-pval'] = np.clip(df['lmm-rank-pval'] * ntests, 0, 1)
df['qep-pval'] = np.clip(df['qep-pval'] * ntests, 0, 1)
# Out:
# Number of tests: 32981

# %%
from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file
from bokeh.charts import BoxPlot, Bar
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="59ce9e3c-71d7-4bf0-82ce-75921f1715bf">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.DataFrame(columns=('pval', 'method', 'color'))

def append_df(data, df, name):
    N = len(df['%s-pval' % name])
    d = [np.asarray(df['%s-pval' % name]), [name] * N]
    data = pd.concat([data, pd.DataFrame({'pval': d[0], 'method': d[1], 'color': ['white'] * N})])
    return data

data = append_df(data, df, 'lmm')
data = append_df(data, df, 'lmm-rank')
data = append_df(data, df, 'qep')

data.loc[data['method'] == 'lmm', 'color'] = 'blue'
data.loc[data['method'] == 'lmm-rank', 'color'] = 'pink'
data.loc[data['method'] == 'qep', 'color'] = 'red'


grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: sum(x<1e-3)})

grouped.loc['lmm', 'color'] = 'blue'
grouped.loc['lmm-rank', 'color'] = 'pink'
grouped.loc['qep', 'color'] = 'red'

p = Bar(grouped, values='pval', color='color', label='method', legend=False,
       title = "Chromossome %d" % (chrom, ), tools=['save,reset'], width=900)
p.yaxis.axis_label = 'Number of hits'
 
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b58b4e62-f835-40a9-9b8a-c4957e8ff559"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b58b4e62-f835-40a9-9b8a-c4957e8ff559").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b58b4e62-f835-40a9-9b8a-c4957e8ff559");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b58b4e62-f835-40a9-9b8a-c4957e8ff559' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"085a5bbd-557c-435e-9c40-014a2eb7c618":{"roots":{"references":[{"attributes":{"callback":null,"factors":["lmm","lmm-rank","qep"]},"id":"00ed1eff-4580-41db-aa20-20a83fdb6fae","type":"FactorRange"},{"attributes":{},"id":"5751e67a-4575-4cbc-aa06-f66cd98745ac","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["width","x","line_alpha","line_color","y","label","color","height","fill_alpha"],"data":{"chart_index":[{"color":"blue","method":"lmm"}],"color":["blue"],"fill_alpha":[0.8],"height":[509.0],"label":[{"color":"blue","method":"lmm"}],"line_alpha":[1.0],"line_color":["white"],"method":["lmm"],"width":[0.8],"x":["lmm"],"y":[254.5]}},"id":"f9b8afbc-a4a9-477b-ba37-5443ff7d8cfd","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"6c9d6ff4-2bd8-4264-8537-b1cce9ee07e2","subtype":"Chart","type":"Plot"},"ticker":{"id":"2abe6415-e01d-49f4-8d14-e500233e9b7d","type":"BasicTicker"}},"id":"52309037-47c7-42e2-9ce2-a36de98b0638","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"051905b4-78be-441a-844a-02362eb26d81","type":"Rect"},{"attributes":{"axis_label":"Number of hits","formatter":{"id":"5751e67a-4575-4cbc-aa06-f66cd98745ac","type":"BasicTickFormatter"},"plot":{"id":"6c9d6ff4-2bd8-4264-8537-b1cce9ee07e2","subtype":"Chart","type":"Plot"},"ticker":{"id":"2abe6415-e01d-49f4-8d14-e500233e9b7d","type":"BasicTicker"}},"id":"57c5b750-7983-40d1-835a-1ac29588cc5a","type":"LinearAxis"},{"attributes":{},"id":"fcd34ea1-244f-44df-8273-078e9ce60a14","type":"CategoricalTickFormatter"},{"attributes":{"plot":null,"text":"Chromossome 22"},"id":"725f50c7-e378-4f26-872e-a324487f84bf","type":"Title"},{"attributes":{"callback":null,"column_names":["width","x","line_alpha","line_color","y","label","color","height","fill_alpha"],"data":{"chart_index":[{"color":"pink","method":"lmm-rank"}],"color":["pink"],"fill_alpha":[0.8],"height":[0.0],"label":[{"color":"pink","method":"lmm-rank"}],"line_alpha":[1.0],"line_color":["white"],"method":["lmm-rank"],"width":[0.8],"x":["lmm-rank"],"y":[0.0]}},"id":"d21acd88-7057-4fa6-ab77-d328da7eb4fd","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d21acd88-7057-4fa6-ab77-d328da7eb4fd","type":"ColumnDataSource"},"glyph":{"id":"051905b4-78be-441a-844a-02362eb26d81","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c686e561-dcad-4fbf-ba74-e223bd814fd6","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"729f8537-0312-401e-8d8c-be490fd1630f","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","x","line_alpha","line_color","y","label","color","height","fill_alpha"],"data":{"chart_index":[{"color":"red","method":"qep"}],"color":["red"],"fill_alpha":[0.8],"height":[538.0],"label":[{"color":"red","method":"qep"}],"line_alpha":[1.0],"line_color":["white"],"method":["qep"],"width":[0.8],"x":["qep"],"y":[269.0]}},"id":"e3326db1-0fc5-442c-a4c3-2c76bd72cd9b","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":564.9},"id":"4617ae9a-065b-4f79-a22a-bf8d58c76b8c","type":"Range1d"},{"attributes":{"plot":{"id":"6c9d6ff4-2bd8-4264-8537-b1cce9ee07e2","subtype":"Chart","type":"Plot"}},"id":"2fa8fed8-2d80-4f9d-b792-145f04d3a879","type":"SaveTool"},{"attributes":{"axis_label":"Method","formatter":{"id":"fcd34ea1-244f-44df-8273-078e9ce60a14","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"6c9d6ff4-2bd8-4264-8537-b1cce9ee07e2","subtype":"Chart","type":"Plot"},"ticker":{"id":"56d9f879-f695-4ec4-8d2b-3cd84b7cc2f0","type":"CategoricalTicke ...
