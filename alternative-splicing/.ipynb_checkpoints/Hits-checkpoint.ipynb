# %%
import pandas as pd
import numpy as np


chrom = 22
df = pd.read_pickle('chrom_%d.pkl' % chrom)
df.set_index(['gene', 'intron'], inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000025770 1          22  0.613807       0.480221  50896901  0.389656
#                 1          22  0.316533       0.574893  50897215  0.533459
#                 1          22  0.043711       0.138918  50897314  0.099098
#                 1          22  0.514677       0.750123  50897692  0.828003
#                 1          22  0.000753       0.021789  50897868  0.007409
#
#                                  snp_id
# gene            intron
# ENSG00000025770 1       snp_22_50896901
#                 1       snp_22_50897215
#                 1       snp_22_50897314
#                 1       snp_22_50897692
#                 1       snp_22_50897868

# %% [markdown]
# # Bonferroni correction

# %%
ntests = len(df.index.unique())
print("Number of tests: %d" % ntests)

# Bonferroni within gene-intron
def pval_agg(x):
    return np.clip(np.min(x) * len(x), 0, 1)

def method_agg(x):
    return x[0]
    
def gene_intron_wise(df):
    df = df.groupby(level=[0, 1]).agg({
        'lmm-pval': pval_agg,
        'lmm-rank-pval': pval_agg,
        'qep-pval': pval_agg
    })
    return df

df = gene_intron_wise(df)
# Out:
# Number of tests: 296

# %%
df.head()
# Out:
#                         qep-pval  lmm-rank-pval      lmm-pval
# gene            intron
# ENSG00000025770 1       1.000000       1.000000  6.825442e-04
#                 2       1.000000       1.000000  4.163024e-06
#                 4       0.192797       0.625935  1.000000e+00
#                 5       1.000000       1.000000  1.000000e+00
#                 6       0.035485       0.194227  8.597851e-08

# %%
data = pd.DataFrame(columns=('pval', 'method'))

def append_df(data, df, name):
    pval = df['%s-pval' % name]
    data = pd.concat([data, pd.DataFrame({'pval': pval, 'method': name})])
    return data

data = append_df(data, df, 'lmm')
data = append_df(data, df, 'lmm-rank')
data = append_df(data, df, 'qep')

# %%
data.head()
# Out:
#                      method          pval
# (ENSG00000025770, 1)    lmm  6.825442e-04
# (ENSG00000025770, 2)    lmm  4.163024e-06
# (ENSG00000025770, 4)    lmm  1.000000e+00
# (ENSG00000025770, 5)    lmm  1.000000e+00
# (ENSG00000025770, 6)    lmm  8.597851e-08

# %%
from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file
from bokeh.charts import BoxPlot, Bar
from bokeh.layouts import gridplot
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a999fc08-3ef6-485d-bd41-16f1c5447dc8">Loading BokehJS ...</span>
#     </div>

# %%
def plot_curve(data, perc=False, exclude=False, lthr=-5, rthr=-0.30103):
    
    nhits = {'lmm-rank':[], 'qep':[]}
    if not exclude:
        nhits['lmm'] = []
    
    pts = np.logspace(lthr, rthr)
    for pt in pts:

        if perc:
            grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: 100*sum(x*len(x)<=pt)/float(len(x))})
        else:
            grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: sum(x*len(x)<=pt)})


        nhits['lmm-rank'].append(grouped.loc['lmm-rank', 'pval'])
        if not exclude:
            nhits['lmm'].append(grouped.loc['lmm', 'pval'])
        nhits['qep'].append(grouped.loc['qep', 'pval'])

    p = figure(title="Power", tools=['save,reset'])
    p.grid.grid_line_alpha=0.3
    p.xaxis.axis_label = 'P-value threshold'
    if perc:
        p.yaxis.axis_label = 'Percentage of hits'
    else:
        p.yaxis.axis_label = 'Number of hits'
    p.line(pts, nhits['lmm-rank'], color='green', legend='lmm-rank')
    if not exclude:
        p.line(pts, nhits['lmm'], color='blue', legend='lmm')
    p.line(pts, nhits['qep'], color='red', legend='qep')
    p.legend.location = "bottom_right"
    return p

# %%
p1 = plot_curve(data, True)
p2 = plot_curve(data, True, True)
p3 = plot_curve(data, False)
p4 = plot_curve(data, False, True)
show(gridplot([[p1,p2],[p3,p4]], plot_width=400, plot_height=400))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c41eb8be-bf67-46d5-8155-fdd0b5cf8c50"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c41eb8be-bf67-46d5-8155-fdd0b5cf8c50").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c41eb8be-bf67-46d5-8155-fdd0b5cf8c50");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c41eb8be-bf67-46d5-8155-fdd0b5cf8c50' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d21b589c-1bdd-44c7-93ac-03f162843e62":{"roots":{"references":[{"attributes":{"plot":{"id":"dddac9d8-a2c7-459e-8a36-7e39a22fdecd","subtype":"Figure","type":"Plot"}},"id":"82ea2da5-b13d-4596-85d3-7922b0d53b24","type":"ResetTool"},{"attributes":{"callback":null},"id":"c5b931c2-133f-47f8-bf9f-6acdfe574a8a","type":"DataRange1d"},{"attributes":{"dimension":1,"grid_line_alpha":{"value":0.3},"plot":{"id":"836fbfa0-521a-4af7-ac91-22111dd5d3cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"828cb1e2-41ae-4d81-b3a9-c33e5a49272c","type":"BasicTicker"}},"id":"734fe63e-1aec-4645-9118-b1a5be509e9c","type":"Grid"},{"attributes":{"plot":null,"text":"Power"},"id":"b3bd3cef-c7b3-4e0d-a272-944ed8b36145","type":"Title"},{"attributes":{"data_source":{"id":"8d24458c-3c5c-455e-8b49-cee4a2880ca4","type":"ColumnDataSource"},"glyph":{"id":"ce5a436e-8eea-482e-bda4-7c5420cf1b06","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"f7c65e2c-ab18-4b56-8a8a-4ba56a3c02c6","type":"Line"},"selection_glyph":null},"id":"7737b46e-ad9c-4877-889e-402b59d9400c","type":"GlyphRenderer"},{"attributes":{},"id":"a93793ff-f076-4dc9-9b94-960df12db30f","type":"BasicTicker"},{"attributes":{"plot":{"id":"b17c28a5-5471-4dc4-b953-ce081f420102","subtype":"Figure","type":"Plot"}},"id":"e7aaa7b8-6cc7-4093-93ac-01f67da2fa2b","type":"ResetTool"},{"attributes":{},"id":"ef342fc4-86f0-46bc-8151-74c430a4b9ad","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"a8062348-d0c1-452c-9736-a82663188b0f","type":"LinearAxis"}],"left":[{"id":"6dc488cc-25be-4146-a314-9d74f2871c23","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"a8062348-d0c1-452c-9736-a82663188b0f","type":"LinearAxis"},{"id":"04f057a2-69fd-402c-a3be-f69e55a4b64c","type":"Grid"},{"id":"6dc488cc-25be-4146-a314-9d74f2871c23","type":"LinearAxis"},{"id":"09868ad2-07c8-4c10-8593-1c0e1d2bd903","type":"Grid"},{"id":"0ee73747-e15d-4199-8dc0-a67d26615fdf","type":"Legend"},{"id":"667c3c0a-6ef1-4c45-8e11-e396fad5c8e2","type":"GlyphRenderer"},{"id":"f910c70d-5be4-44b3-9214-45318038290d","type":"GlyphRenderer"}],"title":{"id":"2d2e5842-10c6-4d76-ac8c-b29fbefd8b7c","type":"Title"},"tool_events":{"id":"9c640735-0962-4b21-923c-9a9255f5a764","type":"ToolEvents"},"toolbar":{"id":"c24e3151-088a-4a18-87aa-6d118bbb0ba0","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"f647dd5d-5ad2-495c-ac19-e487b87b5950","type":"DataRange1d"},"y_range":{"id":"195279cc-89d2-45ec-96c8-71f7e6f338cd","type":"DataRange1d"}},"id":"dddac9d8-a2c7-459e-8a36-7e39a22fdecd","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"dddac9d8-a2c7-459e-8a36-7e39a22fdecd","subtype":"Figure","type":"Plot"}},"id":"a738cb97-0c1a-4932-baee-7747aad34d85","type":"SaveTool"},{"attributes":{"data_source":{"id":"5fb6099c-6532-4b69-972e-3c6c8e92946e","type":"ColumnDataSource"},"glyph":{"id":"4e262d98-19ce-4b66-a800-5b1c183f287c","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"cd0da903-6755-49ba-90ab-f903915993e0","type":"Line"},"selection_glyph":null},"id":"92b349ca-8d23-4ba4-8b17-48a052a4b312","type":"GlyphRenderer"},{"attributes":{"items":[{"id":"e599054a-6c67-4fb3-b0e3-93548b2d8f27","type":"LegendItem"},{"id":"125654ed-78e7-40d2-9560-793b0344023b","type":"LegendItem"},{"id":"8fd825ed-d238-416e-bada-2609bb30ca51","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"836fbfa0-521a-4af7-ac91-22111dd5d3cf","subtype":"Figure","type":"Plot"}},"id":"20eba96b-2f2a-45ef-85de-01d00c58a4e5","type":"Legend"},{"attributes":{},"id":"0c9fc0f1-2152-4545-9cdd-1372a2971b1c","type":"BasicTicker"},{"attributes":{},"id":"46e849e0-b042-459b-9ab4-49a6ba82cdb9","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ca907514-2c6a-4f09-a7db-3cd34ec3687a","type":"Line"},{"attributes":{"plot":null,"text":"Power"},"id":"17ac71a0-11ac-4ce5-9df6-f3e6fbd26a6e","type":"Title"},{"attributes":{"line_alpha":{"value":0.1}, ...

# %%
lthr = -5
rthr = -1
p1 = plot_curve(data, True, lthr=lthr, rthr=rthr)
p2 = plot_curve(data, True, True, lthr=lthr, rthr=rthr)
p3 = plot_curve(data, False, lthr=lthr, rthr=rthr)
p4 = plot_curve(data, False, True, lthr=lthr, rthr=rthr)
show(gridplot([[p1,p2],[p3,p4]], plot_width=400, plot_height=400))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e198bc85-433c-464a-8a3c-163e5e780a29"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e198bc85-433c-464a-8a3c-163e5e780a29").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e198bc85-433c-464a-8a3c-163e5e780a29");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e198bc85-433c-464a-8a3c-163e5e780a29' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c9d7d9e1-1fbf-46a8-a673-dee104c3046e":{"roots":{"references":[{"attributes":{"data_source":{"id":"2439c733-7426-46ea-bb0a-6c90a5614d48","type":"ColumnDataSource"},"glyph":{"id":"2622e12a-1795-4f10-b167-01c29009362f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"4f7493ac-be43-4e1b-bca5-6b169ab8e38f","type":"Line"},"selection_glyph":null},"id":"c2a56096-1308-40a1-b9ec-0b037d7a10eb","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4f7493ac-be43-4e1b-bca5-6b169ab8e38f","type":"Line"},{"attributes":{},"id":"bd61c39b-47d6-4e02-addd-8756982f3ea5","type":"BasicTicker"},{"attributes":{},"id":"693fe67c-1fe6-4199-bd1e-68a9af12927c","type":"BasicTickFormatter"},{"attributes":{"axis_label":"P-value threshold","formatter":{"id":"09786942-09df-4f56-baed-ce24b83e4a44","type":"BasicTickFormatter"},"plot":{"id":"e6e548d0-d866-4c24-9fe1-07398719be6e","subtype":"Figure","type":"Plot"},"ticker":{"id":"5d44ef72-00f8-4bce-8687-4a87b8c7f6fd","type":"BasicTicker"}},"id":"075d0e63-1a54-431f-ae51-952fe0da83e6","type":"LinearAxis"},{"attributes":{"axis_label":"P-value threshold","formatter":{"id":"719a7bcb-10e1-480a-9af4-0bbcb58b5a1b","type":"BasicTickFormatter"},"plot":{"id":"4644384e-b78d-44fc-9ad8-e8c721db3947","subtype":"Figure","type":"Plot"},"ticker":{"id":"c2a5899a-a24e-48dd-9e89-0af9449cef5e","type":"BasicTicker"}},"id":"5ff40c2a-8acd-4abb-b2d5-707e2de62eef","type":"LinearAxis"},{"attributes":{},"id":"0bd78cef-273c-4736-aa17-b24c229afc06","type":"ToolEvents"},{"attributes":{},"id":"e34847e6-bcf1-4b32-9dec-3837955ab773","type":"ToolEvents"},{"attributes":{"callback":null},"id":"a641d581-0531-44ee-bdca-9f4cdc6e94a6","type":"DataRange1d"},{"attributes":{"callback":null},"id":"a12f6b2a-6019-43aa-8870-120804061e02","type":"DataRange1d"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9a730a8c-3739-4f35-869b-0c1a9aa30b04","type":"Line"},{"attributes":{"plot":{"id":"e6e548d0-d866-4c24-9fe1-07398719be6e","subtype":"Figure","type":"Plot"}},"id":"8936f4bb-af47-4bba-be87-786b870169c0","type":"SaveTool"},{"attributes":{},"id":"f16dd17f-d712-44b7-8a9c-1efbffbeb0a2","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"3ce7090d-d0c2-4c83-9079-a70542a44f4e","type":"DataRange1d"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7c1b22bf-da89-4d6b-90b9-ead6aca70bfd","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1e-05,1.2067926406393289e-05,1.4563484775012445e-05,1.757510624854793e-05,2.1209508879201926e-05,2.559547922699533e-05,3.0888435964774785e-05,3.727593720314938e-05,4.498432668969444e-05,5.4286754393238594e-05,6.55128556859551e-05,7.906043210907701e-05,9.540954763499944e-05,0.00011513953993264469,0.00013894954943731373,0.00016768329368110067,0.00020235896477251554,0.000244205309454865,0.00029470517025518097,0.00035564803062231287,0.00042919342601287783,0.0005179474679231213,0.0006250551925273969,0.0007543120063354615,0.0009102981779915217,0.0010985411419875584,0.0013257113655901081,0.0015998587196060573,0.0019306977288832496,0.002329951810515372,0.002811768697974228,0.0033932217718953264,0.004094915062380423,0.004941713361323833,0.005963623316594642,0.007196856730011514,0.00868511373751352,0.010481131341546853,0.012648552168552958,0.015264179671752318,0.018420699693267144,0.022229964825261933,0.026826957952797246,0.032374575428176434,0.039069399370546126,0.047148663634573894,0.05689866029018293,0.06866488450042998,0.08286427728546843,0.1],"y":[3.3783783783783785,3.3783783783783785,3.3783783783783785,3.3783783783783785,3.3783783783783785,3.3783783783783785,3.3783783783783785,3.3783783783783785,3.3783783783783785,3.3783783783783785,3.7162162162162162,3.7162162162162162,3.7162162162162162,3.7162162162162162,3.7162162162162162,3.7162162162162162,3.7162162162162162,3.7162162162162162,3.71621621621 ...

# %%
lthr = -10
rthr = -2
p1 = plot_curve(data, True, lthr=lthr, rthr=rthr)
p2 = plot_curve(data, True, True, lthr=lthr, rthr=rthr)
p3 = plot_curve(data, False, lthr=lthr, rthr=rthr)
p4 = plot_curve(data, False, True, lthr=lthr, rthr=rthr)
show(gridplot([[p1,p2],[p3,p4]], plot_width=400, plot_height=400))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="ceb77e73-c0dc-48cd-ae02-fde013649b42"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#ceb77e73-c0dc-48cd-ae02-fde013649b42").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ceb77e73-c0dc-48cd-ae02-fde013649b42");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ceb77e73-c0dc-48cd-ae02-fde013649b42' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d734e8ce-f624-485e-ae90-2d5115b3169f":{"roots":{"references":[{"attributes":{"label":{"value":"qep"},"renderers":[{"id":"440049c0-3ab2-494f-8124-cddce5869681","type":"GlyphRenderer"}]},"id":"70ed258a-b9ed-43fb-ba8c-4a33a2e316a0","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ad92acde-651a-469b-af70-098e3d3d893a","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b4d4e1a8-65f8-426d-ad87-ef7e068ed67a","type":"Line"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c2c079a-b245-4e91-a084-89975d87c9ac","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"49197075-c680-45e9-99ce-8530ee4d66c5","type":"Line"},{"attributes":{"items":[{"id":"dcc3a317-91c6-46ff-8b6e-778bb6fd026b","type":"LegendItem"},{"id":"70ed258a-b9ed-43fb-ba8c-4a33a2e316a0","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"7cbb5ac1-bfdf-4c39-b55c-19ee9a2f4ddc","subtype":"Figure","type":"Plot"}},"id":"8b0cdd7e-a26c-45c8-b8ac-d516848be9f7","type":"Legend"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"727deb75-c8dc-454d-ac85-11e38dab6838","type":"Line"},{"attributes":{},"id":"96978a22-1849-42d2-94cf-b39b67b2f569","type":"BasicTicker"},{"attributes":{},"id":"7b20ba63-635f-4a42-b226-8eeddf52ac14","type":"BasicTickFormatter"},{"attributes":{},"id":"9264d7ea-e3e3-451b-b20b-d940756d4df6","type":"BasicTicker"},{"attributes":{"plot":{"id":"cc493245-e672-4111-8b5b-9a34a873ee03","subtype":"Figure","type":"Plot"}},"id":"43fb0d35-8739-4117-a577-5a04b2fc20c6","type":"ResetTool"},{"attributes":{"callback":null},"id":"8f0a44f9-5d01-4641-9802-3bb5eabd355d","type":"DataRange1d"},{"attributes":{},"id":"1508ad4e-38e7-4e8d-b46b-960e143fb85b","type":"BasicTicker"},{"attributes":{"data_source":{"id":"7c0cf41d-e7b9-463b-be21-0bdf142c5bda","type":"ColumnDataSource"},"glyph":{"id":"6c2c079a-b245-4e91-a084-89975d87c9ac","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"d8cb223e-f05a-4790-b489-5680c2c14a57","type":"Line"},"selection_glyph":null},"id":"41a3c8d9-d670-4be0-8f39-933e4661523b","type":"GlyphRenderer"},{"attributes":{"items":[{"id":"adcfb946-97ae-47e2-8080-573159d12c6c","type":"LegendItem"},{"id":"5354b003-9cee-4407-9cce-f761ec8a7e2f","type":"LegendItem"},{"id":"4ebdfce6-9e8d-4659-9787-e76f4161e784","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"acb19425-366c-4796-b391-f31a3b1a01c7","subtype":"Figure","type":"Plot"}},"id":"eb8b5402-2c12-4f43-b87c-be00fbfa7e71","type":"Legend"},{"attributes":{"data_source":{"id":"9831828b-709a-425e-bbcc-fb4c88ab6f5e","type":"ColumnDataSource"},"glyph":{"id":"4a48532d-14dd-4bed-9b26-7a6404fda37e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"49197075-c680-45e9-99ce-8530ee4d66c5","type":"Line"},"selection_glyph":null},"id":"b24be79f-901e-4bd9-8d59-7822e2074f8d","type":"GlyphRenderer"},{"attributes":{"label":{"value":"lmm"},"renderers":[{"id":"98f66795-b3e2-4a52-ae2e-1d353ddf40e4","type":"GlyphRenderer"}]},"id":"5354b003-9cee-4407-9cce-f761ec8a7e2f","type":"LegendItem"},{"attributes":{"axis_label":"P-value threshold","formatter":{"id":"633645ac-7ce0-46b0-b422-863eae5fbf9e","type":"BasicTickFormatter"},"plot":{"id":"1eb2c099-6c4b-40fe-b9fa-369ff2dbc8dd","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d71126a-f01d-462c-9474-4e7686f59cb8","type":"BasicTicker"}},"id":"7155ce37-a711-463d-91a9-ebe676433ebd","type":"LinearAxis"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"16ee44a7-5cbd-486c-a548-5e2b946389cd","type":"Line"},{"attributes":{"data_source":{"id":"180205b3-be95-4701-8a8b-2ead067c7398","type":"ColumnDataSource"},"glyph":{"id":"332028d6-ad30-4d9b-a500-c13d82d0097d","type":"Line"},"hover_glyph" ...
