# %%
import pandas as pd
import numpy as np


chrom = 22
df = pd.read_pickle('chrom_%d.pkl' % chrom)
df.set_index(['gene', 'intron'], inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000025770 1          22  0.613807       0.480221  50896901  0.389656
#                 1          22  0.316533       0.574893  50897215  0.533459
#                 1          22  0.043711       0.138918  50897314  0.099098
#                 1          22  0.514677       0.750123  50897692  0.828003
#                 1          22  0.000753       0.021789  50897868  0.007409
#
#                                  snp_id
# gene            intron
# ENSG00000025770 1       snp_22_50896901
#                 1       snp_22_50897215
#                 1       snp_22_50897314
#                 1       snp_22_50897692
#                 1       snp_22_50897868

# %% [markdown]
# # Bonferroni correction

# %%
ntests = len(df)
print("Number of tests: %d" % ntests)
df['lmm-pval'] = np.clip(df['lmm-pval'] * ntests, 0, 1)
df['lmm-rank-pval'] = np.clip(df['lmm-rank-pval'] * ntests, 0, 1)
df['qep-pval'] = np.clip(df['qep-pval'] * ntests, 0, 1)
# Out:
# Number of tests: 137228

# %%
from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file
from bokeh.charts import BoxPlot, Bar
from bokeh.layouts import gridplot
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1f942118-5d16-4157-b3af-1f459d1cd152">Loading BokehJS ...</span>
#     </div>

# %%
def plot_curve(perc=False, exclude=False, lthr=-5, rthr=-0.30103):

    data = pd.DataFrame(columns=('pval', 'method', 'color'))

    def append_df(data, df, name):
        N = len(df['%s-pval' % name])
        # BONFERRONI ACROSS THE ENTIRE SET OF GENE-INTRON PAIRS
        d = [np.asarray(df['%s-pval' % name]), [name] * N]
        data = pd.concat([data, pd.DataFrame({'pval': d[0], 'method': d[1]})])
        return data

    data = append_df(data, df, 'lmm')
    data = append_df(data, df, 'lmm-rank')
    data = append_df(data, df, 'qep')
    
    nhits = {'lmm-rank':[], 'qep':[]}
    if not exclude:
        nhits['lmm'] = []
    
    pts = np.logspace(lthr, rthr)
    for pt in pts:

        if perc:
            grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: 100*sum(x<=pt)/float(len(x))})
        else:
            grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: sum(x<=pt)})


        nhits['lmm-rank'].append(grouped.loc['lmm-rank', 'pval'])
        if not exclude:
            nhits['lmm'].append(grouped.loc['lmm', 'pval'])
        nhits['qep'].append(grouped.loc['qep', 'pval'])

    p = figure(title="Power", tools=['save,reset'])
    p.grid.grid_line_alpha=0.3
    p.xaxis.axis_label = 'P-value threshold'
    if perc:
        p.yaxis.axis_label = 'Percentage of hits'
    else:
        p.yaxis.axis_label = 'Number of hits'
    p.line(pts, nhits['lmm-rank'], color='green', legend='lmm-rank')
    if not exclude:
        p.line(pts, nhits['lmm'], color='blue', legend='lmm')
    p.line(pts, nhits['qep'], color='red', legend='qep')
    p.legend.location = "bottom_right"
    return p

# %%
p1 = plot_curve(True)
p2 = plot_curve(True, True)
p3 = plot_curve(False)
p4 = plot_curve(False, True)
show(gridplot([[p1,p2],[p3,p4]], plot_width=400, plot_height=400))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id
","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"94e07b6d-d41f-43d6-9df9-0b6b75f58d82","subtype":"Figure","type":"Plot"}},"id":"4df86286-b9db-4c8d-ba30-91baf6f9aff5","type":"ResetTool"},{"attributes":{},"id":"ea7a70cf-b5c5-43c5-898d-b54374c5bc5b","type":"BasicTicker"},{"attributes":{"axis_label":"Number of hits","formatter":{"id":"49de3edc-7621-4307-a347-b92e29ef4793","type":"BasicTickFormatter"},"plot":{"id":"94e07b6d-d41f-43d6-9df9-0b6b75f58d82","subtype":"Figure","type":"Plot"},"ticker":{"id":"9d25b7dc-d30d-4af9-85f8-20a9b6c6940b","type":"BasicTicker"}},"id":"25316c0b-1005-4efb-bf51-58e4f54ebd92","type":"LinearAxis"},{"attributes":{"dimension":1,"grid_line_alpha":{"value":0.3},"plot":{"id":"6466acdc-3755-4390-a197-dd55dd324c20","subtype":"Figure","type":"Plot"},"ticker":{"id":"1d117e6e-151a-4d09-b861-440ccd3aceef","type":"BasicTicker"}},"id":"cd2f3409-967e-4bcc-9cf6-bebe722643b0","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1082c31f-c277-46a2-b472-43cdeb6b908e","type":"SaveTool"},{"id":"15fb102f-cede-43dd-8c31-fbe8cd0a887f","type":"ResetTool"}]},"id": ...

# %%
lthr = -5
rthr = -1
p1 = plot_curve(True, lthr=lthr, rthr=rthr)
p2 = plot_curve(True, True, lthr=lthr, rthr=rthr)
p3 = plot_curve(False, lthr=lthr, rthr=rthr)
p4 = plot_curve(False, True, lthr=lthr, rthr=rthr)
show(gridplot([[p1,p2],[p3,p4]], plot_width=400, plot_height=400))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="7dfeccee-f3af-42a6-816b-7e957672326b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#7dfeccee-f3af-42a6-816b-7e957672326b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7dfeccee-f3af-42a6-816b-7e957672326b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7dfeccee-f3af-42a6-816b-7e957672326b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ab1f0aa1-7257-4c1e-8d35-9f4ee1251a41":{"roots":{"references":[{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6fbc6c0b-f882-423a-8700-0765f5be63ae","type":"Line"},{"attributes":{"label":{"value":"lmm-rank"},"renderers":[{"id":"9b00bbd6-b7c6-48c6-8877-aed29ca4852b","type":"GlyphRenderer"}]},"id":"2e578c2d-b0b0-4c35-9163-ac5569e95ad1","type":"LegendItem"},{"attributes":{"plot":null,"text":"Power"},"id":"d32e31c9-f22d-4329-bf50-f5efe3dcbf9e","type":"Title"},{"attributes":{"label":{"value":"lmm-rank"},"renderers":[{"id":"3d46376c-406c-4fd1-bc0f-e064bf1aa4c7","type":"GlyphRenderer"}]},"id":"28db61e6-7aa1-487a-a8c1-a0a6861119df","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3acf953d-3ff9-40d9-846d-1225a457934b","type":"Line"},{"attributes":{},"id":"98ee64e4-2854-4ff2-921e-ad27e1ef70a0","type":"BasicTickFormatter"},{"attributes":{},"id":"7dfe4f86-74c7-4e92-8fb2-29a6deae7758","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1e-05,1.2067926406393289e-05,1.4563484775012445e-05,1.757510624854793e-05,2.1209508879201926e-05,2.559547922699533e-05,3.0888435964774785e-05,3.727593720314938e-05,4.498432668969444e-05,5.4286754393238594e-05,6.55128556859551e-05,7.906043210907701e-05,9.540954763499944e-05,0.00011513953993264469,0.00013894954943731373,0.00016768329368110067,0.00020235896477251554,0.000244205309454865,0.00029470517025518097,0.00035564803062231287,0.00042919342601287783,0.0005179474679231213,0.0006250551925273969,0.0007543120063354615,0.0009102981779915217,0.0010985411419875584,0.0013257113655901