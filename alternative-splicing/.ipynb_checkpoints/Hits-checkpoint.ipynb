# %%
import pandas as pd
import numpy as np


df = pd.read_pickle('chrom_real.pkl')
df.set_index(['gene', 'intron'], inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000000419 5          20  0.230234       0.615790  49508683  0.599888
#                 5          20  0.018827       0.489927  49509175  0.523147
#                 5          20  0.712852       0.302470  49509184  0.240761
#                 5          20  0.484039       0.273795  49511295  0.235351
#                 5          20  0.712852       0.302470  49511352  0.240761
#
#                                  snp_id
# gene            intron
# ENSG00000000419 5       snp_20_49508683
#                 5       snp_20_49509175
#                 5       snp_20_49509184
#                 5       snp_20_49511295
#                 5       snp_20_49511352

# %% [markdown]
# # Bonferroni correction

# %%
ntests = len(df.index.unique())
print("Number of tests: %d" % ntests)

# Bonferroni within gene-intron
def pval_agg(x):
    return np.clip(np.min(x) * len(x), 0, 1)

def method_agg(x):
    return x[0]
    
def gene_intron_wise(df):
    df = df.groupby(level=[0, 1]).agg({
        'lmm-pval': pval_agg,
        'lmm-rank-pval': pval_agg,
        'qep-pval': pval_agg
    })
    return df

df = gene_intron_wise(df)
# Out:
# Number of tests: 68454

# %%
df.head()
# Out:
#                         lmm-rank-pval  lmm-pval  qep-pval
# gene            intron
# ENSG00000000419 5            1.000000  0.094760  1.000000
#                 6            0.405983  0.000951  1.000000
#                 7            1.000000  0.000011  1.000000
#                 8            1.000000  1.000000  1.000000
# ENSG00000000457 1            0.065261  0.191699  0.057588

# %%
data = pd.DataFrame(columns=('pval', 'method'))

def append_df(data, df, name):
    pval = df['%s-pval' % name]
    data = pd.concat([data, pd.DataFrame({'pval': pval, 'method': name})])
    return data

data = append_df(data, df, 'lmm')
data = append_df(data, df, 'lmm-rank')
data = append_df(data, df, 'qep')

# %%
data.head()
# Out:
#                      method      pval
# (ENSG00000000419, 5)    lmm  0.094760
# (ENSG00000000419, 6)    lmm  0.000951
# (ENSG00000000419, 7)    lmm  0.000011
# (ENSG00000000419, 8)    lmm  1.000000
# (ENSG00000000457, 1)    lmm  0.191699

# %%
from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file
from bokeh.charts import BoxPlot, Bar
from bokeh.layouts import gridplot
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0cfab9c4-a545-4028-a122-88775296de0c">Loading BokehJS ...</span>
#     </div>

# %%
def plot_curve(data, perc=False, exclude=False, lthr=-5, rthr=-0.30103):
    
    nhits = {'lmm-rank':[], 'qep':[]}
    if not exclude:
        nhits['lmm'] = []
    
    pts = np.logspace(lthr, rthr)
    for pt in pts:

        if perc:
            grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: 100*sum(x*len(x)<=pt)/float(len(x))})
        else:
            grouped = data.groupby(data['method']).agg({'method': lambda x: x[0], 'pval': lambda x: sum(x*len(x)<=pt)})


        nhits['lmm-rank'].append(grouped.loc['lmm-rank', 'pval'])
        if not exclude:
            nhits['lmm'].append(grouped.loc['lmm', 'pval'])
        nhits['qep'].append(grouped.loc['qep', 'pval'])

    p = figure(title="Power", tools=['save,reset'])
    p.grid.grid_line_alpha=0.3
    p.xaxis.axis_label = 'P-value threshold'
    if perc:
        p.yaxis.axis_label = 'Percentage of hits'
    else:
        p.yaxis.axis_label = 'Number of hits'
    p.line(pts, nhits['lmm-rank'], color='green', legend='lmm-rank')
    if not exclude:
        p.line(pts, nhits['lmm'], color='blue', legend='lmm')
    p.line(pts, nhits['qep'], color='red', legend='qep')
    p.legend.location = "bottom_right"
    return p

# %%
p1 = plot_curve(data, True)
p2 = plot_curve(data, True, True)
p3 = plot_curve(data, False)
p4 = plot_curve(data, False, True)
show(gridplot([[p1,p2],[p3,p4]], plot_width=400, plot_height=400))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c973cfb3-4399-47b8-ba21-c39a34722cf1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c973cfb3-4399-47b8-ba21-c39a34722cf1").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c973cfb3-4399-47b8-ba21-c39a34722cf1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c973cfb3-4399-47b8-ba21-c39a34722cf1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"60483479-cad7-4deb-b72d-a078aaa281ca":{"roots":{"references":[{"attributes":{"plot":null,"text":"Power"},"id":"b05071e4-8f11-4664-8a19-e192f2d65d92","type":"Title"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a082d5e6-5861-4ff4-9893-f988a5dfb4ad","type":"Line"},{"attributes":{},"id":"d2fbe12e-556d-4030-905a-9287d3743a28","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Power"},"id":"3fd69650-18ff-441d-ad60-ba6be41b3e6f","type":"Title"},{"attributes":{"axis_label":"Number of hits","formatter":{"id":"2e88d76f-cfb8-4342-b0ba-fbbc8de04605","type":"BasicTickFormatter"},"plot":{"id":"e004d0bf-4eea-472c-8b92-18e3b7fa6815","subtype":"Figure","type":"Plot"},"ticker":{"id":"f7d18397-14c6-46c3-beac-d3b12fb1d212","type":"BasicTicker"}},"id":"0447e7d1-60c1-486c-be33-34c0a742284c","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a2059fde-bd45-4b32-863a-10a56f00370e","type":"Line"},{"attributes":{},"id":"8a34567d-aebe-4c34-b42a-bfaa9311e90e","type":"BasicTickFormatter"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"e004d0bf-4eea-472c-8b92-18e3b7fa6815","subtype":"Figure","type":"Plot"},"ticker":{"id":"e9255f39-cc6a-4da7-9c9e-30163ca0101c","type":"BasicTicker"}},"id":"356cb788-9d9e-49a8-b166-689861783579","type":"Grid"},{"attributes":{"label":{"value":"qep"},"renderers":[{"id":"75e23a51-014f-41e6-a0f4-f22a5a9fba55","type":"GlyphRenderer"}]},"id":"53f18bd3-df15-443a-a7e9-f48c3f24c038","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[
002329951810515372,0.002811768697974228,0.0033932217718953264,0.004094915062380423,0.004941713361323833,0.005963623316594642,0.007196856730011514,0.00868511373751352,0.010481131341546853,0.012648552168552958,0.015264179671752318,0.018420699693267144,0.022229964825261933,0.026826957952797246,0.032374575428176434,0.039069399370546126,0.047148663634573894,0.05689866029018293,0.06866488450042998,0.08286427728546843,0.1],"y":[1423.0,1434.0,1449.0,1458.0,1480.0,1497.0,1506.0,1523.0,1539.0,1555.0,1570.0,1584.0,1596.0,1618.0,1632.0,1649.0,1662.0,1677.0,1694.0,1713.0,1722.0,1749.0,1768.0,1780.0,1804.0,1824.0,1840.0,1867.0,1883.0,1909.0,1930.0,1953.0,1978.0,2006.0,2023.0,2053.0,2075.0,2094.0,2118.0,2137.0,2164.0,2193.0,2216.0,2246.0,2271.0,2297.0,2332.0,2371.0,2397.0,2428.0]}},"id":"2474b3f3-b9b1-48e6-af1d-df13e5cacd19","type":"ColumnDataSource"},{"attributes":{},"id":"6c457e12-5068-452b-99e8-0ee79e170d9c","type":"BasicTicker"},{"attributes":{"data_source":{"id":"573dfb23-c85d-4c03-a431-84132cd ...

# %%
lthr = -10
rthr = -2
p1 = plot_curve(data, True, lthr=lthr, rthr=rthr)
p2 = plot_curve(data, True, True, lthr=lthr, rthr=rthr)
p3 = plot_curve(data, False, lthr=lthr, rthr=rthr)
p4 = plot_curve(data, False, True, lthr=lthr, rthr=rthr)
show(gridplot([[p1,p2],[p3,p4]], plot_width=400, plot_height=400))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="eef90be0-263f-41b1-82d8-f8eb21b61aa9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#eef90be0-263f-41b1-82d8-f8eb21b61aa9").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eef90be0-263f-41b1-82d8-f8eb21b61aa9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eef90be0-263f-41b1-82d8-f8eb21b61aa9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"427800c7-2103-4647-ac1c-1ba86cb04d8c":{"roots":{"references":[{"attributes":{},"id":"fd68ddb8-be5b-44d5-a5ad-34a7de439cff","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bbf3aa99-1622-44f6-99a5-5be73890499d","type":"Line"},{"attributes":{"data_source":{"id":"49738ff7-5ef2-456f-98aa-ff08c476e577","type":"ColumnDataSource"},"glyph":{"id":"12e0f5b5-f0fe-4376-b855-dffe34274187","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"6f5f5fce-f17a-4340-a062-2334b7db54d3","type":"Line"},"selection_glyph":null},"id":"fcb8842d-1104-464e-ba5b-20309df2f500","type":"GlyphRenderer"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"d46cb64a-8276-444b-bad7-69a5785e109c","subtype":"Figure","type":"Plot"},"ticker":{"id":"25d07706-3f1d-4994-b899-23da3e36fd82","type":"BasicTicker"}},"id":"acaec4ab-7fec-4722-b29d-1c2cd7ae1da0","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"98a02195-d89f-4424-8a05-a98dacf6b232","type":"Line"},{"attributes":{"label":{"value":"qep"},"renderers":[{"id":"909b4d8e-056b-4a1c-81f3-6eea2e0348d5","type":"GlyphRenderer"}]},"id":"d337b789-f01d-4148-b75f-e5d694ffdb63","type":"LegendItem"},{"attributes":{"data_source":{"id":"e681f4d6-f72b-4ab8-98ce-d9d12cc32b66","type":"ColumnDataSource"},"glyph":{"id":"bc540d9d-a813-49ed-93a7-d3d0fa943e25","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"8eb5de5c-d1f8-4745-a90b-d0bf37085ffd","type":"Line"},"selection_glyph":null},"id":"76e4ea88-5db6-4629-b9c6-351f5717af97","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5b518e58-3537-477e-8d9c-76bb2fb5a22d","subtype":"Figure","type":"Plot"}},"id":"ab8ac95b-1bd6-45df-ba73-bf898ed226f6","type":"SaveTool"},{"attributes":{"children":[{"id":"e3e0e6dc-720e-4783-a66d-2411e62a0357","type":"ToolbarBox"},{"id":"6a74b324-c3a0-4965-9c4b-e7a11ae444c2","type":"Column"}]},"id":"3c541aa4-f1f9-42b8-bb73-4f78611353a7","type":"Column"},{"attributes":{"below":[{"id":"199dae26-fd0a-450b-8b79-3a3adbb5c1c4","type":"LinearAxis"}],"left":[{"id":"dc565229-5c32-4792-a28a-5aa432f0842d","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"199dae26-fd0a-450b-8b79-3a3adbb5c1c4","type":"LinearAxis"},{"id":"d4b6b89a-be80-4bd2-a517-384e0672135c","type":"Grid"},{"id":"dc565229-5c32-4792-a28a-5aa432f0842d","type":"LinearAxis"},{"id":"cb6e76b4-29f5-4f30-a426-4124ce8b2062","type":"Grid"},{"id":"7e8561ac-e14e-40b6-9e9f-f345b9f8244d","type":"Legend"},{"id":"8cc81a4b-405b-47b8-8126-8598b6a4285b","type":"GlyphRenderer"},{"id":"4ee63f1d-3b71-4ca6-bf2c-86613ef73ce7","type":"GlyphRenderer"}],"title":{"id":"abcfccc1-d7fb-4a2f-a73a-bced50efa44b","type":"Title"},"tool_events":{"id":"08fa8fb8-531b-41b1-bd5f-d156751c7509","type":"ToolEvents"},"toolbar":{"id":"3914e144-a2c3-48b1-b836-75e42bc2075b","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"8a04a3b6-b761-48e2-97de-038625b4fa74","type":"DataRange1d"},"y_range":{"id":"602f414d-c02f-47ab-bedf-91844ba287e2","type":"DataRange1d"}},"id":"5b518e58-3537-477e-8d9c-76bb2fb5a22d","subtype":"Figure","type":"Plot"},{"attributes":{"label":{"value":"qep"},"renderers":[{"id":"76e4ea88-5db6-4629-b9c6-351f5717af97","type":"GlyphRenderer"}]},"id":"7fb61137-c6e8-4405-a2c4-e339ee0bf99d","type":"LegendItem"},{"attributes":{"callback":null},"id":"715d8601-b014-4269-89b6-5230ca7f50aa","type":"DataRange1d"},{"attributes":{"label":{"value":"lmm-rank"},"renderers":[{"id":"dde6079c-c7d9-43d9-9ac6-60d62766236d","type":"GlyphRenderer"}]},"id":"9fd7f555-5fa6-44d5-a137-8523f0122181","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d90042c-3f64-4bcb-87a0-70b3f33e7ed6","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f5f5fc ...
