# %%
import pandas as pd
import numpy as np

from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file


import numpy as np
import colour
from scipy.special import betaincinv
from limix_plot import cycler_ as cycler
from collections import OrderedDict
from numpy import asarray as asa

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="02be5217-cd1e-4724-ab46-742ce164d124">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_pickle('chrom_null.pkl')
df.set_index(['gene', 'intron'], inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000000419 5          20  0.477324       0.406138  42131442  0.386107
#                 5          20  0.039244       0.014254  42131753  0.009565
#                 5          20  0.573356       0.590113  42132193  0.654554
#                 5          20  0.825621       0.945350  42132273  0.963257
#                 5          20  0.910330       0.857315  42132314  0.891363
#
#                                       snp_id
# gene            intron
# ENSG00000000419 5            snp_19_42131442
#                 5       indel:1I_19_42131753
#                 5            snp_19_42132193
#                 5            snp_19_42132273
#                 5            snp_19_42132314

# %%
def expected(n):
    lnpv = np.linspace(1/(n+1), n/(n+1), n, endpoint=True)
    return np.flipud(-np.log10(lnpv))

def xy(pv):
    
    return 

def rank_confidence_band(nranks):
    alpha = 0.01
    n = nranks
    k0 = np.arange(1, n+1)
    k1 = np.flipud(k0).copy()
    mean = k0 / (n + 1)
    return mean

def qqplot(p, method, color, df0, thr=1e-1, fill_alpha=0.2):
    
    pv = df0['%s-pval' % method].values[:]
    lpv = -np.log10(pv)
    lpv_sort = np.argsort(lpv)
    expected_lpv = expected(len(lpv))

    ok = pv[lpv_sort] <= thr
    
    gene = asa([i[0] for i in df0.index.values[lpv_sort]])
    intron = asa([i[1] for i in df0.index.values[lpv_sort]])
    
    source = ColumnDataSource(data=dict(
        xname=expected_lpv[ok],
        yname=lpv[lpv_sort][ok],
        gene=gene[ok],
        intron=intron[ok],
        snp_id=df0['snp_id'][lpv_sort][ok],
        pval=pv[lpv_sort][ok],
        pos=df0['pos'][lpv_sort][ok]
    ))
    
    p.circle('xname', 'yname', source=source, color=color,
             fill_alpha=fill_alpha, line_width=0, line_color=None,
            legend=method)
    
    mean = rank_confidence_band(len(lpv))
    me = [-np.log10(m) for m in mean]
    p.line([me[0], me[-1]], [me[0], me[-1]], color='black')
    p.legend.location = 'top_left'
    return p

# %%
crazy_pheno = ('ENSG00000171735', 6)
DF = df.loc[crazy_pheno]

# %%
DF.head()
# Out:
#                         chrom  lmm-pval  lmm-rank-pval       pos  qep-pval  \
# gene            intron
# ENSG00000171735 6           1  0.887536       0.996717  32500351  0.922672
#                 6           1  0.180603       0.164092  32500485  0.369977
#                 6           1  0.180603       0.164092  32500704  0.369977
#                 6           1  0.071100       0.070651  32500710  0.047345
#                 6           1  0.160643       0.178178  32501006  0.303750
#
#                                       snp_id
# gene            intron
# ENSG00000171735 6            snp_22_32500351
#                 6            snp_22_32500485
#                 6       indel:1I_22_32500704
#                 6            snp_22_32500710
#                 6            snp_22_32501006

# %%
DF['lmm-rank-pval'].min()
# Out:
# 0.00091881246591822249

# %%
from horta_exp.introns.fetch_data import get_intron_events
introns = get_intron_events()
introns.head()
# Out:
#                                        assay  nsuc  ntri
# gene            intron
# ENSG00000000419 5       HG00096.1.M_111124_6    37   347
#                 5       HG00097.7.M_120219_2    68   451
#                 5       HG00099.1.M_120209_6    31   327
#                 5       HG00099.5.M_120131_3    34   289
#                 5       HG00100.2.M_111215_8    35   281

# %%
introns.loc[crazy_pheno]
# Out:
#                                        assay  nsuc  ntri
# gene            intron
# ENSG00000171735 6       HG00096.1.M_111124_6   178   310
#                 6       HG00097.7.M_120219_2   139   226
#                 6       HG00099.1.M_120209_6    83   165
#                 6       HG00099.5.M_120131_3   116   212
#                 6       HG00100.2.M_111215_8    90   159
#                 6       HG00101.1.M_111124_4   125   177
#                 6       HG00102.3.M_120202_8    71   142
#                 6       HG00103.4.M_120208_3   136   253
#                 6       HG00104.1.M_111124_5   100   170
#                 6       HG00105.1.M_120209_7   118   214
#                 6       HG00105.3.M_120223_6   257   484
#                 6       HG00106.4.M_120208_5   146   267
#                 6       HG00108.7.M_120219_2   151   226
#                 6       HG00109.1.M_120209_4    88   149
#                 6       HG00110.2.M_120131_2   160   277
#                 6       HG00111.1.M_120209_8   114   188
#                 6       HG00111.2.M_111215_4   195   337
#                 6       HG00112.6.M_120119_2   104   202
#                 6       HG00114.1.M_120209_3   135   221
#                 6       HG00114.6.M_120217_1    73   145
#                 6       HG00115.6.M_120119_1   121   213
#                 6       HG00116.2.M_120131_1   111   218
#                 6       HG00117.1.M_111124_2   232   395
#                 6       HG00118.4.M_120208_5   152   279
#                 6       HG00119.1.M_120209_3   104   162
#                 6       HG00119.2.M_111216_6   162   269
#                 6       HG00120.3.M_120202_2    92   143
#                 6       HG00121.1.M_111124_7   121   199
#                 6       HG00122.6.M_120119_1   193   329
#                 6       HG00123.4.M_120208_7   161   302
# ...                                      ...   ...   ...
#                 6       NA20785.4.M_120208_1   243   433
#                 6       NA20786.2.M_111215_8   145   286
#                 6       NA20787.6.M_120119_3   137   239
#                 6       NA20790.2.M_111215_6    92   162
#                 6       NA20792.6.M_120119_6   123   190
#                 6       NA20795.5.M_120131_1   119   215
#                 6       NA20796.1.M_120209_2   267   415
#                 6       NA20797.2.M_111215_6   167   282
#                 6       NA20798.6.M_120119_6    91   183
#                 6       NA20799.1.M_111124_3   156   247
#                 6       NA20800.1.M_111124_5   150   271
#                 6       NA20801.7.M_120219_5   188   303
#                 6       NA20802.1.M_111124_7   176   315
#                 6       NA20803.7.M_120219_1   242   446
#                 6       NA20804.4.M_120208_1   104   209
#                 6       NA20805.4.M_120208_7    61   125
#                 6       NA20806.3.M_120202_5   112   175
#                 6       NA20807.5.M_120131_1   107   198
#                 6       NA20808.4.M_120208_6   167   287
#                 6       NA20809.6.M_120119_2   138   213
#                 6       NA20810.2.M_111215_7   269   434
#                 6       NA20811.1.M_111124_5   115   205
#                 6       NA20812.2.M_111216_6   142   257
#                 6       NA20813.5.M_120131_1   153   274
#                 6       NA20814.2.M_111215_6   137   239
#                 6       NA20815.5.M_120131_5   159   316
#                 6       NA20816.3.M_120202_7   112   223
#                 6       NA20819.3.M_120202_2   112   181
#                 6       NA20826.1.M_111124_1   141   258
#                 6       NA20828.2.M_111216_8   271   477
#
# [571 rows x 3 columns]

# %%
introns.loc[crazy_pheno]['nsuc'].unique()
# Out:
# array([ 178,  139,   83,  116,   90,  125,   71,  136,  100,  118,  257,
#         146,  151,   88,  160,  114,  195,  104,  135,   73,  121,  111,
#         232,  152,  162,   92,  193,  161,  157,   89,  165,  176,  102,
#         101,   86,  143,  119,  124,  108,   77,  201,   84,  130,  128,
#         137,  181,  207,  206,   58,  140,  142,  185,   51,  313,  149,
#         117,   98,  223,  164,   55,   67,   64,   63,   91,   80,  163,
#         159,   96,  170,  262,  145,  175,  192,   93,  147,  115,  216,
#         208,  123,  314,  188,  120,  127,  112,  144,  105,   41,   97,
#         113,  106,  246,  131,  285,   50,  141,  134,   60,   87,  166,
#         180,   74,  173,   81,  132,   45,  182,  174,   79,   70,   66,
#         228,  122,  155,   65,  103,   62,   85,   56,  184,   54,   53,
#          78,   38,   75,  156,  110,   68,   48,   57,   37,   99,  133,
#          72,   52,   59,  249,   47,  107,   95,  109,  158,  179,   49,
#         154,  226,   40,   39,   24,  394,   44,   69,   76,  186,   35,
#         279,  247,  167,   29,  298, 3172,   61,   42,  126,  169,  138,
#         148,  129,  224,  296,   82,  153,  222,  200,  227,   94,  214,
#         172,  191,  243,  267,  150,  242,  269,  271])

# %%
np.mean(introns.loc[crazy_pheno]['nsuc']/introns.loc[crazy_pheno]['ntri'])
# Out:
# 0.5726997831634896
