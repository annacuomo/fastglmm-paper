# %%
import pandas as pd
import numpy as np

from horta_exp.introns.fetch_data import get_intron_events

from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file
from bokeh.charts import BoxPlot, Bar, Histogram
from bokeh.layouts import gridplot
from bokeh.layouts import gridplot

FILE = 'chrom_real_all.pkl'
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="80b77640-79eb-431d-afcc-1ff84f200b18">Loading BokehJS ...</span>
#     </div>

# %%
introns = get_intron_events()
df = pd.read_pickle(FILE)
df.set_index(['gene', 'intron'], inplace=True)
df.sort_index(inplace=True)

# %%
ii = introns.index.intersection(df.index)
introns = introns.loc[ii,:].sort_index()

# %% [markdown]
# # Bonferroni correction

# %%
ntests = len(df.index.unique())
print("Number of tests: %d" % ntests)

# Bonferroni within gene-intron
def pval_agg(x):
    return np.clip(np.min(x) * len(x), 0, 1)

def method_agg(x):
    return x[0]
    
def gene_intron_wise(df):
    return df.groupby(level=[0, 1]).agg({
        'lmm-pval': pval_agg,
        'lmm-rank-pval': pval_agg,
        'qep-pval': pval_agg
    })

df = gene_intron_wise(df)
# Out:
# Number of tests: 66489

# %%
def method_column(df):
    newdata = pd.DataFrame(columns=('pval', 'method'))

    def append_df(data, df, name):
        pval = df['%s-pval' % name]
        return pd.concat([data, pd.DataFrame({'pval': pval, 'method': name})])
        return data

    newdata = append_df(newdata, df, 'lmm')
    newdata = append_df(newdata, df, 'lmm-rank')
    newdata = append_df(newdata, df, 'qep')
    return newdata

# %%
def set_index(data):
    data = method_column(data)
    data.reset_index(inplace=True)
    data['gene'] = data['index'].apply(lambda x: x[0])
    data['intron'] = data['index'].apply(lambda x: int(x[1]))
    del data['index']
    data.set_index(['gene', 'intron'], inplace=True)
    data.sort_index(inplace=True)
    return data

# %%
df = set_index(df)

# %%
def plot_curve(data, perc=False, exclude=False, lthr=-5, rthr=-0.30103):
    
    nhits = {'lmm-rank':[], 'qep':[]}
    if not exclude:
        nhits['lmm'] = []
    
    pts = np.logspace(lthr, rthr)
    for pt in pts:

        if perc:
            grouped = data.groupby(data['method']).agg({
                'pval': lambda x: 100*sum(x*len(x)<=pt)/float(len(x))
            })
        else:
            grouped = data.groupby(data['method']).agg({
                'pval': lambda x: sum(x*len(x)<=pt)
            })


        nhits['lmm-rank'].append(grouped.loc['lmm-rank', 'pval'])
        if not exclude:
            nhits['lmm'].append(grouped.loc['lmm', 'pval'])
        nhits['qep'].append(grouped.loc['qep', 'pval'])

    p = figure(title="Power", tools=['save,reset'])
    p.grid.grid_line_alpha=0.3
    p.xaxis.axis_label = 'P-value threshold'
    if perc:
        p.yaxis.axis_label = 'Percentage of hits'
    else:
        p.yaxis.axis_label = 'Number of hits'
    p.line(pts, nhits['lmm-rank'], color='green', legend='lmm-rank')
    if not exclude:
        p.line(pts, nhits['lmm'], color='blue', legend='lmm')
    p.line(pts, nhits['qep'], color='red', legend='qep')
    p.legend.location = "bottom_right"
    return p

# %%
def plot_grid(introns, group, df, expression, STAT, q,):
    df = df.loc[expression]
    
    group = group.loc[expression]
    msg = '####### %s stratified (%.2f quantile) -- %d gene-introns #######' % (STAT, q, len(group))
    print('                   %s' % msg)
    
    lthr = -5
    rthr = -1
    p1 = plot_curve(df, False, lthr=lthr, rthr=rthr)
    p2 = plot_curve(df, False, True, lthr=lthr, rthr=rthr)
    
    def choice(vals):
        return np.random.RandomState(0).choice(vals, min(5000, len(vals)))
    
    ntris = choice(introns['ntri'].values)
    h0 = Histogram(ntris, title="Number of trials - across samples",
                   tools=['save'], xlabel='number of trials',
                   width=400, height=400)
    
    values = choice(group.values)
    h1 = Histogram(values, title="Number of trials - across gene-intron pairs",
                   tools=['save'], xlabel='number of trials', width=400, height=400)
    
    
    show(gridplot([[p1,p2], [h0, h1]], plot_width=400, plot_height=400))
    print()
    print()
    print()

# %%
group = introns.groupby(level=[0, 1]).agg({
    'ntri': {
        'max': 'max',
        'min': 'min',
        'median': 'median',
        'var': 'var',
        'mean': 'mean',
    }
})
group.sort_index(inplace=True)

# %% [markdown]
# # Stratified by median

# %%
STAT = 'median'
for v in [0.0, 0.25, 0.5,  0.75, 0.9]:
    expression = group['ntri'][STAT] > group['ntri'][STAT].quantile(v)
    plot_grid(introns, group['ntri'][STAT], df, expression, STAT, v)
# Out:
#                    ####### median stratified (0.00 quantile) -- 66484 gene-introns #######
#     <div class="bk-root">
#         <div class="plotdiv" id="6280145d-01da-4cb3-8331-c1fb0de55f38"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#6280145d-01da-4cb3-8331-c1fb0de55f38").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6280145d-01da-4cb3-8331-c1fb0de55f38");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6280145d-01da-4cb3-8331-c1fb0de55f38' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"aeada6c6-9fae-44d6-b9e6-42346c8b2aad":{"roots":{"references":[{"attributes":{"data_source":{"id":"f71a8b99-8c10-4133-bb72-26b0090f2b8d","type":"ColumnDataSource"},"glyph":{"id":"341ae589-495f-4042-bc96-12dd44a3ec8c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1163e4c2-1f8f-45fa-a4b8-053cc62b52df","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3395def4-243d-499f-8079-865d646f5265","type":"Rect"},{"attributes":{"data_source":{"id":"1c9b6bf0-1004-4fbe-8fd4-2a2ae66bb719","type":"ColumnDataSource"},"glyph":{"id":"9085a03a-cf3d-484d-85d7-cbb7448938ba","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a8276c05-e150-4a14-a173-69f7a74cc827","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4bc70aa0-1492-4da8-a409-93d72310c1d7","type":"Rect"},{"attributes":{"data_source":{"id":"140607c9-a536-4200-a873-a434fedbca0a","type":"ColumnDataSource"},"glyph":{"id":"be9e7c5e-32d7-4ba4-86df-4dd06ca148eb","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1ccb39a9-56f0-45b7-a544-626e39a59a30","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["[1.0, 19.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[246.0],"label":["[1.0, 19.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[17.955223880597014],"x":["10.0"],"y":[123.0]}},"id":"567535f9-99e0-481c-8126-c25eabdf8b3a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e88a4f1b-f502-40f8-a5f9-0186a62fa407","type":"ColumnDataSource"},"glyph":{"id":"56f24df2-7646-4a62-9c7c-d47f000013af","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"62152cb2-1a00-4ecd-aa06-46db70dc8760","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4c5112e0-3068-41e0-84e3-dfd6645cc77d","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1f97a2e9-7ed1-4e99-992a-2614965e1637","type":"Rect"},{"attributes":{"data_source":{"id":"0f13708b-9161-4444-afe7-f5fdf97122d3","type":"ColumnDataSource"},"glyph":{"id":"3d2c1e73-75f4-44d9-b1ce-64c45fd8c5d8","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":
type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"13eaeb6c-9a61-47ea-a98c-c327055d2eff","type":"GlyphRenderer"},{"id":"3ce5be16-14ec-4e7d-90ca-4da490d611bd","type":"GlyphRenderer"},{"id":"54042fe6-7040-40d8-8222-b0c7f5d969c5","type":"GlyphRenderer"},{"id":"492af78b-36ec-4a1e-bb17-9fdff2b0c060","type":"GlyphRenderer"},{"id":"baca65ac-1edf-43f4-ae0e-5e0fb3318c1c","type":"GlyphRenderer"} ...

# %% [markdown]
# # Stratified by variance

# %%
STAT = 'var'
for v in [0.0, 0.25, 0.5,  0.75, 0.9]:
    expression = group['ntri'][STAT] > group['ntri'][STAT].quantile(v)
    plot_grid(introns, group['ntri'][STAT], df, expression, STAT, v)
# Out:
#                    ####### var stratified (0.00 quantile) -- 66488 gene-introns #######
#     <div class="bk-root">
#         <div class="plotdiv" id="1c368963-a3b2-4165-9121-187cebbad60f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1c368963-a3b2-4165-9121-187cebbad60f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1c368963-a3b2-4165-9121-187cebbad60f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1c368963-a3b2-4165-9121-187cebbad60f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"deac97f0-add7-416a-b3fb-b9ae9e96248f":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"08e2f977-3a93-4531-8c84-aa86b8f3a71e","type":"Rect"},{"attributes":{"data_source":{"id":"614e4056-ce09-4d15-bb0e-b6e2424b456d","type":"ColumnDataSource"},"glyph":{"id":"c9af0a5c-38c8-4ac5-bbb7-4a3de102ba03","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e71b7049-2c5b-4dce-9e67-9c0563256942","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1e-05,1.2067926406393289e-05,1.4563484775012445e-05,1.757510624854793e-05,2.1209508879201926e-05,2.559547922699533e-05,3.0888435964774785e-05,3.727593720314938e-05,4.498432668969444e-05,5.4286754393238594e-05,6.55128556859551e-05,7.906043210907701e-05,9.540954763499944e-05,0.00011513953993264469,0.00013894954943731373,0.00016768329368110067,0.00020235896477251554,0.000244205309454865,0.00029470517025518097,0.00035564803062231287,0.00042919342601287783,0.0005179474679231213,0.0006250551925273969,0.0007543120063354615,0.0009102981779915217,0.0010985411419875584,0.0013257113655901081,0.0015998587196060573,0.0019306977288832496,0.002329951810515372,0.002811768697974228,0.0033932217718953264,0.004094915062380423,0.004941713361323833,0.005963623316594642,0.007196856730011514,0.00868511373751352,0.010481131341546853,0.012648552168552958,0.015264179671752318,0.018420699693267144,0.022229964825261933,0.026826957952797246,0.032374575428176434,0.039069399370546126,0.047148663634573894,0.05689866029018293,0.06866488450042998,0.08286427728546843,0.1],"y":[1420.0,1434.0,1448.0,1460.0,1478.0,1495.0,1505.0,1522.0,1537.0,1554.0,1567.0,1581.0,1597.0,1615.0,1628.0,1644.0,1657.0,1673.0,1688.0,1708.0,1716.0,1745.0,1762.0,1775.0,1801.0,1817.0,1835.0,1860.0,1877.0,1904.0,1922.0,1944.0,1971.0,1996.0,2012.0,2044.0,2068.0,2085.0,2107.0,2130.0,2153.0,2182.0,2206.0,2230.0,2256.0,2285.0,2322.0,2359.0,2381.0,2413.0]}},"id":"3b58cc77-22a4-447b-a07d-4b26e3d3ab30","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(2513.1, 3749.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[507.0],"label":["(2513.1, 3749.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[1236.8004945229386],"x":["3131.5"],"y":[253.5]}},"id":"62346a6b-7933-4d9b-95c1-e647394b0264","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"763d5b9a-648e-4b5a-80fa-ffda1b28dfc0","type":"Rect"},{"attributes":{"plot":{"id":"51652af3-1614-4419-aa95-05db9b3b66a8","subtype":"Chart","type":"Plot"}},"id":"e99908c4-8407-401d-8de6-46d3406125ca","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(39617.1, 40853.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[11.0],"label":["(39617.1, 40853.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[1236.8004945229404],"x":["40235.5"],"y":[5.5]}},"id":"f06e33d9-52b3-4a87-bf2a-52be0e41e113","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(26012.3, 27249.1]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[40.0],"label":["(26012.3, 27249.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[1236.8004945229368],"x":["26630.699999999997"],"y":[20.0]}},"id":"73d18500-8000-48a0-83e9-5fbcb9ca7cd9","type":"ColumnDataSo ...
#                    ####### var stratified (0.25 quantile) -- 49866 gene-introns #######
#     <div class="bk-root">
#         <div class="plotdiv" id="70e6529c-7063-4e0a-84c9-48bd36fd0191"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#70e6529c-7063-4e0a-84c9-48bd36fd0191").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("70e6529c-7063-4e0a-84c9-48bd36fd0191");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '70e6529c-7063-4e0a-84c9-48bd36fd0191' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {
gene-introns #######
#     <div class="bk-root">
#         <div class="plotdiv" id="a89bdf91-69e2-4e5b-84e2-ac515cb24571"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a89bdf91-69e2-4e5b-84e2-ac515cb24571").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a89bdf91-69e2-4e5b-84e2-ac515cb24571");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a89bdf91-69e2-4e5b-84e2-ac515cb24571' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ea499b34-733d-4de8-a6d3-024bc8392526":{"roots":{"references":[{"attributes":{"data_source":{"id":"65a59818-35c4-407a-9b63-c6692e6cb55f","type":"ColumnDataSource"},"glyph":{"id":"a2279307-bc6f-4b21-b1a1-c9430d009dd8","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c3653dd6-ff47-4493-82b3-7b619fa204b9","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c2f94a0c-21b2-4c1e-aff9-889359d26403","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f47aa5d2-e395-4a34-b957-685f4504b5f1","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e0c723e3-713c-49b2-9435-dfb4a8c9e48a","type":"Rect"},{"attributes":{"data_source":{"id":"c6f44465-15bd-4166-b5c5-e800633f8eb0","type":"ColumnDataSource"},"glyph":{"id":"b95d6f7d-dc64-48e0-99aa-c5bf9c690126","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"75c31e68-10b6-45f0-b12f-76916f891e2b","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e918d4aa-e5e0-4d19-9148-8daf5f7d63ec","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2f1062c8-9a8a-406b-8c6b-d068dbe5d4f6","type":"Rect"},{"attributes":{"data_source":{"id":"97cbddc0-e83a-471f-8d8e-e6183331b6a0","type":"ColumnDataSource"},"glyph":{"id":"5964981d-6c5b-4681-a6b1-cd21c7b9eff0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"eb10bb1e-ad39-4d14-8c2c-c1c1eb29432e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"05fbeba4-461d-4042-92af-dd021854287e","type":"ColumnDataSource"},"glyph":{"id":"25d3154e-63c8-45cf-9248-e7245b712d89","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"89c5697e-b667-4123-b14c-8fdef9959140","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(265009.4, 265985.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(265009.4, 265985.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[976.4920534692355],"x":["265497.65"],"y":[0.0]}},"id":"baa1edab-d985-4ee1-b02e-241290b5ddfd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4a8c2585-190f-4e24-be52-83a6abfb913f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5694239e-2fde-4e75-914e-2b6f90fdb196","type":"Rect"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(163454.2, 16 ...

# %% [markdown]
# # Stratified by mean

# %%
STAT = 'mean'
for v in [0.0, 0.25, 0.5,  0.75, 0.9]:
    expression = group['ntri'][STAT] > group['ntri'][STAT].quantile(v)
    plot_grid(introns, group['ntri'][STAT], df, expression, STAT, v)
# Out:
#                    ####### mean stratified (0.00 quantile) -- 66488 gene-introns #######
#     <div class="bk-root">
#         <div class="plotdiv" id="8fb32cd7-1ea5-48f3-ba3c-eda09c33622b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#8fb32cd7-1ea5-48f3-ba3c-eda09c33622b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8fb32cd7-1ea5-48f3-ba3c-eda09c33622b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8fb32cd7-1ea5-48f3-ba3c-eda09c33622b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1d3a6ec3-8759-4697-960b-c6b01d6362c6":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4d7cec3e-da65-4282-af5c-285a72c00fe5","type":"Rect"},{"attributes":{"data_source":{"id":"c6504645-bfc5-4dbc-b01e-25c7382d4f90","type":"ColumnDataSource"},"glyph":{"id":"1fe51539-82ec-4c03-ab73-4c5c47493c07","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ddca008f-15d4-4a59-ab2e-02403106c9da","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(809.0, 826.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":["(809.0, 826.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[17.955223880597032],"x":["817.95"],"y":[1.5]}},"id":"fd136787-878e-4b5d-a723-c49ba94b90a2","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(124.9, 141.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[303.0],"label":["(124.9, 141.4]"],"line_alpha":[1.0],"line_color":["black"],"width":
type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"79b109d8-2bae-401d-b3e5-cc1ab3ff6993","type":"Rect"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(360.1, 378.1]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[62.0],"label":["(360.1, 378.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[17.955223880596975],"x":["369.1"],"y":[31.0]}},"id":"5657b917-f0a9-4186-8635-637ef371f940","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(291.5, 302.3]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[303.0],"label":["(291.5, 302.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.765807113956157],"x":["296.9"],"y":[151.5]}},"id":"f925a824-7f7b-429a-a579-3f67d4be5283","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(54.9, 72.8]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[461.0],"label":["(54.9, 72.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[17.955223880597018],"x":["63.849999999999994"],"y":[230.5]}},"id":"f4d9733f-86fd-4fdc-8117-8c2b803b70f9","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(557.6, 575.6]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[13.0],"label":["(557.6, 575.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[17.955223880597032],"x":["566.6"],"y":[6.5]}},"id":"5d62a690-1c8a-480c-81b8-77a626f4ffc7","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(791.0, 809.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(791.0, 809.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[17.955223880597032],"x":["800.0"],"y":[1.0]}},"id":"0fc10051-b7c9-4930-97a4-c886122210d0","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data" ...
#                    ####### mean stratified (0.90 quantile) -- 6649 gene-introns #######
#     <div class="bk-root">
#         <div class="plotdiv" id="24f540cb-fb7c-4003-a388-24a1620272f6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#24f540cb-fb7c-4003-a388-24a1620272f6").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("24f540cb-fb7c-4003-a388-24a1620272f6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '24f540cb-fb7c-4003-a388-24a1620272f6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f0ae7614-3c30-4b96-ac6d-bb8fff72e326":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"12c7cc61-1f73-4bed-a19b-365b74c69cc0","type":"Rect"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(665.3, 683.3]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":["(665.3, 683.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[17.955223880597032],"x":["674.3"],"y":[1.5]}},"id":"fa68d88a-1091-419a-aef0-52d0d04561da","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f3dbc76d-0d38-4373-af04-83e5c160d0ee","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1e-05,1.2067926406393289e-05,1.4563484775012445e-05,1.757510624854793e-05,2.1209508879201926e-05,2.559547922699533e-05,3.0888435964774785e-05,3.727593720314938e-05,4.498432668969444e-05,5.4286754393238594e-05,6.55128556859551e-05,7.906043210907701e-05,9.540954763499944e-05,0.00011513953993264469,0.00013894954943731373,0.00016768329368110067,0.00020235896477251554,0.000244205309454865,0.00029470517025518097,0.00035564803062231287,0.00042919342601287783,0.0005179474679231213,0.0006250551925273969,0.0007543120063354615,0.0009102981779915217,0.0010985411419875584,0.0013257113655901081,0.0015998587196060573,0.0019306977288832496,0.002329951810515372,0.002811768697974228,0.0033932217718953264,0.004094915062380423,0.004941713361323833,0.005963623316594642,0.007196856730011514,0.00868511373751352,0.010481131341546853,0.012648552168552958,0.015264179671752318,0.018420699693267144,0.022229964825261933,0.026826957952797246,0.032374575428176434,0.039069399370546126,0.047148663634573894,0.05689866029018293,0.06866488450042998,0.08286427728546843,0.1],"y":[111.0,113.0,114.0,114.0,115.0,116.0,117.0,120.0,122.0,124.0,128.0,128.0,131.0,132.0,133.0,134.0,135.0,135.0,136.0,140.0,142.0,143.0,146.0,147.0,150.0,150.0,153.0,154.0,155.0,157.0,159.0,162.0,164.0,172.0,174.0,180.0,184.0,186.0,191.0,193.0,197.0,206.0,210.0,216.0,219.0,222.0,227.0,233.0,236.0,241.0]}},"id":"72a4c64f-784d-4be3-ad31-b4e0713dfa53","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d7d06da2-9f06-4e8d-8866-e054a17d8adf","type":"ColumnDataSource"},"glyph":{"id":"c4c50e00-03c8-4bee-b025-0fc8a93833f7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"da9b86dd-c424-43f1-8a67-a26a1e6dfab1","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(1132.2, 1150.1]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(1132.2, 1150.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[17.955223880597032],"x":["1141.15"],"y":[0.0]}},"id":"786a2661-dc85-4f95-8170-ab77360d8ca1","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":1234.1026119402986,"start":-29.102611940298516},"id":"78196016-facc-47ee-a22c-b774c9eedccd","type":"Range1d"},{"attributes":{"callback":null,"column_names":["label","width","color","x","line_color","height","y","fill_alpha","line_alpha"],"data":{"chart_index":["(414.3, 421.3]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[136.0],"label":["(414.3, 421.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[7.076344295258423],"x":["417.8"],"y":[68.0]}},"id":"2309fb1a-5544-4b31-8d5d-2592fcc5cea5","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c9d5dcb0-7fa6-4686-8b30-347e7ee5fec5","type":"ColumnDataSou ...
