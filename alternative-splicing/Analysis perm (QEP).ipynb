# %%
import pandas as pd
import numpy as np


chrom = 22
df = pd.read_pickle('chrom_%d_perm.pkl' % chrom)
df.set_index(['gene', 'intron'], inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                         chrom  lmm-pval       pos  qep-pval           snp_id
# gene            intron
# ENSG00000015475 6          22  0.488160  18183494  0.442632  snp_22_18183494
#                 6          22  0.512587  18183623  0.703575  snp_22_18183623
#                 6          22  0.047945  18183724  0.059372  snp_22_18183724
#                 6          22  0.513477  18184011  0.493602  snp_22_18184011
#                 6          22  0.379372  18184169  0.429686  snp_22_18184169

# %% [markdown]
# # Bonferroni correction

# %%
ntests = len(df)
print("Number of tests: %d" % ntests)
df['lmm-pval'] = np.clip(df['lmm-pval'] * ntests, 0, 1)
df['qep-pval'] = np.clip(df['qep-pval'] * ntests, 0, 1)
# Out:
# Number of tests: 815240

# %%
df.head()
# Out:
#                         chrom  lmm-pval       pos  qep-pval           snp_id
# gene            intron
# ENSG00000015475 6          22       1.0  18183494       1.0  snp_22_18183494
#                 6          22       1.0  18183623       1.0  snp_22_18183623
#                 6          22       1.0  18183724       1.0  snp_22_18183724
#                 6          22       1.0  18184011       1.0  snp_22_18184011
#                 6          22       1.0  18184169       1.0  snp_22_18184169

# %%
from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file
output_notebook()


def manhattan(method, color, df0):
    df0 = df0[df0['%s-pval' % method] < 1e-1]

    p = figure(title = "%s :: chromossome %d" % (method.upper(), chrom),
               tools=['hover,zoom_in,zoom_out,box_zoom,save,pan,reset'], width=900)
    source = ColumnDataSource(data=dict(
        xname=df0['pos'],
        yname=-np.log10(df0['%s-pval' % method]),
        gene=[i[0] for i in df0.index.values],
        intron=[i[1] for i in df0.index.values],
        snp_id=df0['snp_id'],
        pval=df0['%s-pval' % method.lower()],
        pos=df0['pos']
    ))
    p.circle('xname', 'yname', source=source, color=color,
             fill_alpha=0.2, line_width=0, line_color=None)
    p.select_one(HoverTool).tooltips = [
        ('gene', '@gene'),
        ('intron', '@intron'),
        ('snp_id', '@snp_id'),
        ('pos', '@pos'),
        ('p-value', '@pval'),
    ]
    show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d9c8cdcb-95ac-49e4-8d20-1e9e97efd240">Loading BokehJS ...</span>
#     </div>

# %%
manhattan('qep', 'red', df)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="128700a1-99c8-4cc7-9255-c4b745a51991"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#128700a1-99c8-4cc7-9255-c4b745a51991").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("128700a1-99c8-4cc7-9255-c4b745a51991");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '128700a1-99c8-4cc7-9255-c4b745a51991' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"692e3f16-2c1e-41d2-a8f7-4b19a2334e9c":{"roots":{"references":[{"attributes":{"plot":null,"text":"QEP :: chromossome 22"},"id":"aa1d5d35-d5aa-4096-82cd-dfe980723dfe","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"19bcfe40-fbce-4209-9dd7-b08d520842a3","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"2110306c-942b-4a03-8017-ae76235e7385","subtype":"Figure","type":"Plot"}},"id":"61ec1ff6-e8f8-48eb-bf1f-03b224b0ff55","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0},"x":{"field":"xname"},"y":{"field":"yname"}},"id":"455e7971-aadf-417f-abc5-f9bf8b0b0f98","type":"Circle"},{"attributes":{},"id":"1daa87de-a3c5-4203-95d6-b872617ed116","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2aa4759b-8997-498b-81f6-fcb15d718d43","type":"HoverTool"},{"id":"334117df-e837-418a-b2f9-435ff88d8427","type":"ZoomInTool"},{"id":"5dfb22ed-d021-47c5-8367-8e0ab32af1ed","type":"ZoomOutTool"},{"id":"19e0a8f8-dc1e-4454-8d73-16cf2bc71d31","type":"BoxZoomTool"},{"id":"9dfad0f8-84af-4f8e-a199-da7f3e9802a3","type":"SaveTool"},{"id":"4bbe045f-506b-492a-b374-e97a9d17a439","type":"PanTool"},{"id":"61ec1ff6-e8f8-48eb-bf1f-03b224b0ff55","type":"ResetTool"}]},"id":"f704442d-006e-452d-873e-45740f39b793","type":"Toolbar"},{"attributes":{"plot":{"id":"2110306c-942b-4a03-8017-ae76235e7385","subtype":"Figure","type":"Plot"}},"id":"4bbe045f-506b-492a-b374-e97a9d17a439","type":"PanTool"},{"attributes":{"callback":null},"id":"18c8f0dd-5419-4733-85ba-56fd811878aa","type":"DataRange1d"},{"attributes":{},"id":"50b845ab-0193-4264-b732-b414acb313d4","type":"BasicTicker"},{"attributes":{"plot":{"id":"2110306c-942b-4a03-8017-ae76235e7385","subtype":"Figure","type":"Plot"},"ticker":{"id":"50b845ab-0193-4264-b732-b414acb313d4","type":"BasicTicker"}},"id":"82334956-35be-436e-8340-2509f2a819fc","type":"Grid"},{"attributes":{"below":[{"id":"8ce2285f-0fda-4db6-8040-11386619be55","type":"LinearAxis"}],"left":[{"id":"6961fddf-aba2-4b11-80c2-6c7e1ffdc242","type":"LinearAxis"}],"plot_width":900,"renderers":[{"id":"8ce2285f-0fda-4db6-8040-11386619be55","type":"LinearAxis"},{"id":"82334956-35be-436e-8340-2509f2a819fc","type":"Grid"},{"id":"6961fddf-aba2-4b11-80c2-6c7e1ffdc242","type":"LinearAxis"},{"id":"375a06ea-588a-426f-8dd0-9e3f517f0dfa","type":"Grid"},{"id":"19bcfe40-fbce-4209-9dd7-b08d520842a3","type":"BoxAnnotation"},{"id":"a3318f02-ed6c-4c19-bc32-f50d2ea99d0d","type":"GlyphRenderer"}],"title":{"id":"aa1d5d35-d5aa-4096-82cd-dfe980723dfe","type":"Title"},"tool_events":{"id":"8eab52b5-3101-4861-ab19-a486a82962d0","type":"ToolEvents"},"toolbar":{"id":"f704442d-006e-452d-873e-45740f39b793","type":"Toolbar"},"x_range":{"id":"6e080eac-bba2-48a8-9423-9b33e5dfc8f2","type":"DataRange1d"},"y_range":{"id":"18c8f0dd-5419-4733-85ba-56fd811878aa","type":"DataRange1d"}},"id":"2110306c-942b-4a03-8017-ae76235e7385","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"red"},"line_color":{"value":null},"line_width":{"value":0},"x":{"field":"xname"},"y":{"field":"yname"}},"id":"038d17a8-baf2-47c2-ac64-e36d84505283","type":"Circle"},{"attributes":{"data_source":{"id":"3874fb6f-fcd7-40e5-8f65-b0974005bd78","type":"ColumnDataSource"},"glyph":{"id":"038d17a8-baf2-47c2-ac64-e36d84505283","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"455e7971-aadf-417f-abc5-f9bf8b0b0f98","type":"Circle"},"selection_glyph":null},"id":"a3318f02-ed6c-4c19-bc32-f50d2ea99d0d","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"2110306c-942b-4a ...
