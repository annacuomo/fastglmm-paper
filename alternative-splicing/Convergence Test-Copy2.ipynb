# %%
import pandas as pd
import numpy as np

from horta_exp.introns.fetch_data import get_intron_events

from limix_genetics import hitsplot
from bokeh.io import push_notebook, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show, output_file
from bokeh.charts import BoxPlot, Bar, Histogram
from bokeh.layouts import gridplot

FILE = {'real': 'chrom_real_all.pkl', 'null': 'chrom_null_all.pkl'}
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f41c1ba6-3180-48d8-ab6f-7e22e01cb6a9">Loading BokehJS ...</span>
#     </div>

# %%
def convert_and_save(filename):
    introns = get_intron_events()
    df = pd.read_pickle(filename).set_index(['gene', 'intron']).sort_index()
    introns = introns.loc[df.index.drop_duplicates()]

    introns.to_pickle('introns_%s.pkl' % filename)
    df.to_pickle('df_%s.pkl' % filename)
    
    return (introns, df)

# %%
introns = dict()
df = dict()

if True:
    for n in ['real', 'null']:
        introns[n] = pd.read_pickle('introns_%s.pkl' % FILE[n])
        df[n] = pd.read_pickle('df_%s.pkl' % FILE[n])
else:
    for n in ['real', 'null']:
        (introns[n], df[n]) = convert_and_save(FILE[n])

# %%
npairs = len(df['real'].index.unique())
print("Number of gene-intron pairs: %d" % npairs)
# Out:
# Number of gene-intron pairs: 66507

# %% [markdown]
# # Bonferroni correction within gene-introns and aggregate the p-values

# %%
def bonferroni_and_aggregate(df):
    def pval_agg(x):
        return np.clip(np.min(x) * len(x), 0, 1)

    return df.groupby(level=[0, 1]).agg({
        'lmm-pval': pval_agg,
        'lmm-rank-pval': pval_agg,
        'qep-pval': pval_agg
    })

for n in ['real', 'null']:
    df[n] = bonferroni_and_aggregate(df[n])

# %%
from IPython.display import display
for n in ['real', 'null']:
    display(df[n].head())
# Out:
#                         lmm-rank-pval  qep-pval  lmm-pval
# gene            intron
# ENSG00000000419 5            1.000000  1.000000  1.000000
#                 6            0.405983  1.000000  1.000000
#                 7            1.000000  1.000000  0.820634
#                 8            1.000000  1.000000  1.000000
# ENSG00000000457 1            0.065261  0.057588  0.007733
#                         lmm-rank-pval  qep-pval  lmm-pval
# gene            intron
# ENSG00000000419 5            1.000000   1.00000  1.000000
#                 6            1.000000   1.00000  1.000000
#                 7            1.000000   1.00000  1.000000
#                 8            0.408914   0.38103  0.278223
# ENSG00000000457 1            1.000000   1.00000  0.039725

# %%
def method_column(df):
    newdata = pd.DataFrame(columns=('pval', 'method'))

    def append_df(data, df, name):
        pval = df['%s-pval' % name]
        return pd.concat([data, pd.DataFrame({'pval': pval, 'method': name})])
        return data

    newdata = append_df(newdata, df, 'lmm')
    newdata = append_df(newdata, df, 'lmm-rank')
    newdata = append_df(newdata, df, 'qep')
    return newdata

def set_index(data):
    data = method_column(data)
    data.reset_index(inplace=True)
    data['gene'] = data['index'].apply(lambda x: x[0])
    data['intron'] = data['index'].apply(lambda x: int(x[1]))
    del data['index']
    data.set_index(['gene', 'intron'], inplace=True)
    data.sort_index(inplace=True)
    return data

DF = dict()
for n in ['real', 'null']:
    DF[n] = set_index(df[n])
    DF[n] = DF[n].rename(columns={'method':'label', 'pval':'p-value'})

# %%
for n in ['real', 'null']:
    display(DF[n].head())
# Out:
#                            label   p-value
# gene            intron
# ENSG00000000419 5            lmm  1.000000
#                 5       lmm-rank  1.000000
#                 5            qep  1.000000
#                 6            lmm  1.000000
#                 6       lmm-rank  0.405983
#                            label  p-value
# gene            intron
# ENSG00000000419 5            lmm      1.0
#                 5       lmm-rank      1.0
#                 5            qep      1.0
#                 6            lmm      1.0
#                 6       lmm-rank      1.0

# %%
group = introns['real'].groupby(level=[0, 1]).agg({
    'ntri': {
        'max': 'max',
        'min': 'min',
        'median': 'median',
        'var': 'var',
        'mean': 'mean',
    }
})
group.sort_index(inplace=True)

# %%
group.head()
# Out:
#                               ntri
#                               mean   max median           var  min
# gene            intron
# ENSG00000000419 5       355.765324   951    347  19941.576410   29
#                 6       221.404553   675    218   8380.139558    8
#                 7       294.374781   863    291  14244.062801   28
#                 8       447.775832  1243    449  33432.223345  104
# ENSG00000000457 1       443.460595  1309    432  33727.862918   73

# %%
def plot_grid(DF, ntri, introns, STAT):
    
    size = 400
    colors={'lmm': 'blue', 'qep': 'red', 'lmm-rank': 'green'}
    
    df = DF['real'].loc[ntri.index].copy()
    df['p-value'] = np.clip(df['p-value'] * npairs, 0, 1)
    
    f0 = hitsplot(df,
                  colors=colors,
         perc=True, width=size, height=size, min_threshold=1e-5, max_threshold=1e-2,
        show=False)
    
    df = DF['null'].loc[ntri.index].copy()
    df['p-value'] = np.clip(df['p-value'] * npairs, 0, 1)
    
    f1 = hitsplot(df, colors=colors,
         perc=True, width=size, height=size, min_threshold=1e-5, max_threshold=1e-2,
        show=False)

    
    def choice(vals):
        return np.random.RandomState(0).choice(vals, min(5000, len(vals)))
    
    ntris = choice(introns.loc[ntri.index]['ntri'].values)
    h0 = Histogram(ntris, title="Number of trials - across samples",
                   tools=['save'], xlabel='number of trials',
                   width=size, height=size)
    
    values = choice(ntri[STAT].values)
    h1 = Histogram(values, title="%s number of trials - across gene-intron pairs" % STAT,
                   tools=['save'], xlabel='number of trials', width=size, height=size)
    
    
    show(gridplot([[f0, f1], [h0, h1]]))

# %%
ntri = group['ntri'].copy()
ntri = ntri[ntri['min'] > 30]
ntri = ntri[ntri['var'] < ntri['var'].quantile(0.10)]
plot_grid(DF, ntri, introns['real'], 'min')
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0a617d44-af11-475e-8658-7a6916396596"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#0a617d44-af11-475e-8658-7a6916396596").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0a617d44-af11-475e-8658-7a6916396596");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0a617d44-af11-475e-8658-7a6916396596' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cd48a495-e8ec-411f-a067-3f2bd2736a52":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"22df8733-5a7f-4dc6-9c4c-98987a8866c3","type":"Rect"},{"attributes":{"plot":null,"text":"hitsplot"},"id":"52009e51-8d55-4de8-8fa2-65ea70374e3d","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0a59b5ba-3d46-4de3-8787-9abb1ee72315","type":"Rect"},{"attributes":{"data_source":{"id":"8cb7f010-5ff0-4217-91b5-79c0a4bf0287","type":"ColumnDataSource"},"glyph":{"id":"76cd1778-d273-4372-8c46-6d90ac918bc7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"44a09bac-f54d-41e6-8ca6-c3578f33057d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0b2ae3dd-2b10-49eb-bb27-830fcfd70037","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(73.4, 84.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[232.0],"label":["(73.4, 84.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.606557377049185],"x":["78.7"],"y":[116.0]}},"id":"0f9a97be-821e-43ea-a230-4815036e93a0","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c11b1772-ea34-43e7-9ddc-67e14205521d","type":"ColumnDataSource"},"glyph":{"id":"261292cc-6e3a-4dd0-8ee9-7483bc998304","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b21cf02a-3957-4ebe-ab5e-a2678d6ddad5","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(391.6, 402.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[7.0],"label":["(391.6, 402.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.606557377049171],"x":["396.9"],"y":[3.5]}},"id":"5a95f6f8-a013-4891-b40e-e2e433a3d10a","type":"ColumnDataSource"},{"attributes":{"axis_label":"Count( A )","formatter":{"id":"0c4920ca-6145-4e43-b37c-ec6cad371135","type":"BasicTickFormatter"},"plot":{"id":"76da2607-78c3-4bf6-b74c-4cbe69972d90","subtype":"Chart","type":"Plot"},"ticker":{"id":"88e771a8-acb9-487c-a8d1-4be305a7a5ae","type":"BasicTicker"}},"id":"6978a04c-c159-4ff3-9204-762d33cb5493","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"76cd1778-d273-4372-8c46-6d90ac918bc7","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(53.1, 54.6]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(53.1, 54.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.4761904761904745],"x":["53.85"],"y":[0.5]}},"id":"9e52e63b-133c-4341-9bab-c0498711acbe","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(603.8, 614.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(603.8, 614.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.606557377049171],"x":["609.0999999999999"],"y":[0.0]}},"id":"a78f0c4d-8abf-45b9-b9fd-78871a ...

# %%
ntri = group['ntri'].copy()
ntri = ntri[ntri['min'] > 30]
ntri = ntri[ntri['var'] < ntri['var'].quantile(0.20)]
plot_grid(DF, ntri, introns['real'], 'min')
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="d9464867-0a4e-40a5-acd7-6535bc1f9c25"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#d9464867-0a4e-40a5-acd7-6535bc1f9c25").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d9464867-0a4e-40a5-acd7-6535bc1f9c25");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd9464867-0a4e-40a5-acd7-6535bc1f9c25' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"55dd343a-bee8-46d2-8ef5-c84ed0d732e8":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"caac8b4c-f1f5-4dff-8122-3223d653f788","type":"Rect"},{"attributes":{"axis_label":"Count( A )","formatter":{"id":"050dbedf-b870-4b3a-8127-f2d21ece0a96","type":"BasicTickFormatter"},"plot":{"id":"b03ea6bb-27ca-4fb9-8997-5e36cc3a79a4","subtype":"Chart","type":"Plot"},"ticker":{"id":"1d873727-2aa4-42f8-987c-dfc167c06100","type":"BasicTicker"}},"id":"625c36b5-832f-4c91-84a6-158ee4ba2d19","type":"LinearAxis"},{"attributes":{"data_source":{"id":"903e0f39-b4fe-4110-9b62-f56d87e27b89","type":"ColumnDataSource"},"glyph":{"id":"8ba9d900-295a-44a5-ba59-07472afd9535","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3c6cc659-fcdb-4667-b7e6-5d4ecda7573a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(332.4, 344.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[38.0],"label":["(332.4, 344.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[12.55769230769232],"x":["338.65"],"y":[19.0]}},"id":"7a236216-f3e0-4fd4-b166-da9ba89099e7","type":"ColumnDataSource"},{"attributes":{},"id":"f6a51870-1762-4d1d-b390-1ff93dd10aa3","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e8b3ea2-5761-47c9-a8f4-e6f59b4a6880","type":"Rect"},{"attributes":{"plot":{"id":"f534289c-21f5-4d49-b0e3-d4778c9f1831","subtype":"Figure","type":"Plot"}},"id":"6b4ad937-a89c-4dfd-89bc-e2c91e727dfa","type":"SaveTool"},{"attributes":{"plot":null,"text":"hitsplot"},"id":"b7d17639-ad1c-4020-8cd6-fed6a37f3f86","type":"Title"},{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(45.4, 46.7]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[29.0],"label":["(45.4, 46.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.3076923076923066],"x":["46.05"],"y":[14.5]}},"id":"bc8089a8-26bc-4442-a5fd-27605cb6028a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"792ce4b7-64e2-45ac-a0b1-65201fe01e4c","type":"ColumnDataSource"},"glyph":{"id":"93de084e-fbd3-41da-9452-e2fc9425bfb6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"14659613-e264-46a7-9346-2ccc1528a6ce","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"9d142650-d59c-4a61-b36e-e180c10854df","type":"ColumnDataSource"},"glyph":{"id":"066df15c-b197-4394-a19d-28cfd864877e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"211a3500-741f-4594-9f7c-6f8df56111aa","type":"GlyphRenderer"},{"attributes":{"axis_label":"percentage of hits","formatter":{"id":"b98ffcc1-896c-4bc3-900d-c2685e2a83db","type":"BasicTickFormatter"},"plot":{"id":"f534289c-21f5-4d49-b0e3-d4778c9f1831","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5964914-12e6-4ab2-956b-3313db6c4d09","type":"BasicTicker"}},"id":"63ea2d59-ccc9-485c-b05a-5a8a026b9627","type":"LinearAxis"},{"attributes":{"plot":null,"text":"hitsplot"},"id":"6b0c9dc5-65f5-484a-b9f5-8ab9e78b4631","type":"Title"},{"attributes":{"data_source":{"id":"9af85436-547f-4a4d-93e6-86d5b6522908","type":"ColumnDataSource"},"glyph":{"id":"8866742a-3d1a-4c0f-8e23-f914f3b18a90","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ac69ed2c-01a7-46f5-85ca-c87be6fd2016","type":"GlyphRenderer"},{"attributes":{},"id":"e5964914-12e6-4ab2-956b-3313db6c4d09","type": ...

# %%
ntri = group['ntri'].copy()
ntri = ntri[ntri['min'] > 30]
ntri = ntri[ntri['var'] < ntri['var'].quantile(0.30)]
plot_grid(DF, ntri, introns['real'], 'min')
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1e6f8120-979e-4067-976f-bbd20f7003d0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1e6f8120-979e-4067-976f-bbd20f7003d0").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1e6f8120-979e-4067-976f-bbd20f7003d0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1e6f8120-979e-4067-976f-bbd20f7003d0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5dc29ffb-6517-4bdb-adb6-c8af4444c88c":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(52.8, 54.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[51.0],"label":["(52.8, 54.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.452380952380956],"x":["53.5"],"y":[25.5]}},"id":"77340b61-27e5-4558-b5d0-3aec025ee558","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(71.7, 73.1]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(71.7, 73.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.4523809523809632],"x":["72.4"],"y":[1.0]}},"id":"afcd394f-3f7a-4d59-b662-e9f2db537020","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(539.2, 552.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(539.2, 552.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[13.706896551724185],"x":["546.05"],"y":[0.5]}},"id":"4ccffa63-7dc8-46e5-bfb6-79adb731550d","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(59.4, 73.1]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[165.0],"label":["(59.4, 73.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[13.706896551724135],"x":["66.25"],"y":[82.5]}},"id":"b39aca8f-cb9a-43de-aa53-1bcbfd524de1","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(182.8, 196.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[315.0],"label":["(182.8, 196.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[13.706896551724128],"x":["189.65"],"y":[157.5]}},"id":"c7f92dd4-9e46-4da7-8cb6-e3159232c596","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b6a493b8-6861-4e33-abd3-b9d62ce9e563","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f1956cdd-0d9b-4714-a13a-4b44e0113892","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1e-05,0.00011090909090909092,0.00021181818181818183,0.0003127272727272728,0.0004136363636363637,0.0005145454545454546,0.0006154545454545456,0.0007163636363636364,0.0008172727272727274,0.0009181818181818183,0.0010190909090909092,0.0011200000000000001,0.001220909090909091,0.001321818181818182,0.0014227272727272728,0.0015236363636363637,0.0016245454545454547,0.0017254545454545456,0.0018263636363636366,0.0019272727272727273,0.0020281818181818183,0.0021290909090909095,0.00223,0.002330909090909091,0.002431818181818182,0.002532727272727273,0.002633636363636364,0.0027345454545454548,0.0028354545454545455,0.0029363636363636367,0.0030372727272727274,0.0031381818181818186,0.0032390909090909093,0.00334,0.0034409090909090913,0.003541818181818182,0.003642727272727273,0.003743636363636364,0.0038445454545454547,0.003945454545454545,0.004046363636363636,0.004147272727272727,0.0042481818181818185,0.004349090909090909,0.00445,0.004550909090909091,0.0046518181818181814,0.004752727272727273,0.004853636363636364,0.0049545454545454545,0.005055454545454545,0.005156363636363636,0.005257272727272728,0.005358181818181818,0.005459090909090909,0.00556,0.00566090909090 ...

# %%
ntri = group['ntri'].copy()
ntri = ntri[ntri['min'] > 30]
ntri = ntri[ntri['var'] < ntri['var'].quantile(0.40)]
plot_grid(DF, ntri, introns['real'], 'min')
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="156ca86a-907c-4337-b68d-82173ee92077"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#156ca86a-907c-4337-b68d-82173ee92077").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("156ca86a-907c-4337-b68d-82173ee92077");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '156ca86a-907c-4337-b68d-82173ee92077' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"037d38d3-a176-4604-96cb-7f5d17fc74c1":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","line_alpha","height","fill_alpha","line_color","label","color","width","y"],"data":{"chart_index":["(943.8, 958.6]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(943.8, 958.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[14.72307692307686],"x":["951.2"],"y":[0.0]}},"id":"83e57957-9310-4f8b-9cb5-497c05b21f16","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6906d206-7514-4921-997a-66d9fbf367cd","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"39eb031c-ef2c-4858-bb9a-81782b934465","type":"Rect"},{"attributes":{},"id":"808ac43f-ea48-45a8-842b-176cc1516708","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ee16b97-cbad-4f07-a55c-d729f015a82e","type":"Rect"},{"attributes":{"data_source":{"id":"c6d903d4-5b8d-498d-94b2-50513dc8fe68","type":"ColumnDataSource"},"glyph":{"id":"db300776-ec5f-45af-adfc-8f3d8351a78e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d035ec28-e767-4405-a127-fdd84ac32266","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e5b3db00-692b-40a6-adee-bfcbb7aced0a","type":"ColumnDataSource"},"glyph":{"id":"f7941fdb-2e91-4e6c-882c-79596aff9e8d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2e19a96e-5a5b-4e28-a6b7-0fa990901c9f","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"3cc5d97c-cab8-42fb-aee8-38fe586c7713","subtype":"Figure","type":"Plot"},{"id":"3bc8d69f-87ad-4fb3-8048-12c74643af5d","subtype":"Figure","type":"Plot"}]},"id":"c26429aa-a890-4027-9175-dd34c3279a8e","type":"Row"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1e-05,0.00011090909090909092,0.00021181818181818183,0.0003127272727272728,0.0004136363636363637,0.0005145454545454546,0.0006154545454545456,0.0007163636363636364,0.0008172727272727274,0.0009181818181818183,0.0010190909090909092,0.0011200000000000001,0.001220909090909091,0.001321818181818182,0.0014227272727272728,0.0015236363636363637,0.0016245454545454547,0.0017254545454545456,0.0018263636363636366,0.0019272727272727273,0.0020281818181818183,0.0021290909090909095,0.00223,0.002330909090909091,0.002431818181818182,0.002532727272727273,0.002633636363636364,0.0027345454545454548,0.0028354545454545455,0.0029363636363636367,0.0030372727272727274,0.0031381818181818186,0.0032390909090909093,0.00334,0.0034409090909090913,0.003541818181818182,0.003642727272727273,0.003743636363636364,0.0038445454545454547,0.003945454545454545,0.004046363636363636,0.004147272727272727,0.0042481818181818185,0.004349090909090909,0.00445,0.004550909090909091,0.0046518181818181814,0.004752727272727273,0.004853636363636364,0.0049545454545454545,0.005055454545454545,0.005156363636363636,0.005257272727272728,0.005358181818181818,0.005459090909090909,0.00556,0.005660909090909091,0.005761818181818182,0.005862727272727273,0.005963636363636364,0.006064545454545454,0.006165454545454545,0.006266363636363637,0.0063672727272727275,0.006468181818181818,0.006569090909090909,0.00667,0.006770909090909091,0.006871818181818182,0.006972727272727273,0.0070736363636363635,0.007174545454545454,0.007275454545454546,0.007376363636363637,0.007477272727272727,0.007578181818181818,0.007679090909090909,0.0077800000000000 ...
